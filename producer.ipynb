# %%
import time
import re
from confluent_kafka import Producer

# Kafka producer configuration
conf = {
    'bootstrap.servers': 'localhost:9092',  # Replace with your Kafka broker address
    'client.id': 'file-producer'
}
producer = Producer(conf)

# File path (change to your .txt file path)
file_path = 'shakespeare.txt'

# Word occurrence dictionary
word_count = {}

# Delivery report callback function
def delivery_report(err, msg):
    if err is not None:
        print(f"Message delivery failed: {err}")
    else:
        print(f"Message delivered to {msg.topic()} [{msg.partition}] at offset {msg.offset()}")

# Function to send data to Kafka topic
def send_to_kafka(content, cursor_pos):
    try:
        # Send message to Kafka topic 'file-streaming'
        producer.produce('file-streaming', key=str(cursor_pos).encode('utf-8'), value=content.encode('utf-8'), callback=delivery_report)
        producer.flush()  # Ensure message is sent immediately
        print(f"Sent content at position {cursor_pos}: {content.strip()}")
    except Exception as e:
        print(f"Error while sending message: {e}")

    # Track word occurrences
    words = re.findall(r'\w+', content.lower())  # Split content into words (case insensitive)
    for word in words:
        word_count[word] = word_count.get(word, 0) + 1

    # Log word count for the content
    print(f"Updated word count (last 5 words): {dict(list(word_count.items())[-5:])}")  # Show last 5 words added

# Function to process and send content from the .txt file
def process_file():
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            print(f"Processing file: {file_path}")
            
            # Read file line by line
            cursor_pos = 0
            for line in file:
                cursor_pos += len(line)  # Increment cursor position by the length of the line
                print(f"Processing line at position {cursor_pos}, content: {line.strip()}")
                send_to_kafka(line, cursor_pos)
                time.sleep(0.5)  # Simulate real-time processing
            print(f"Completed processing of file: {file_path}")
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found. Please check the file path.")
    except Exception as e:
        print(f"Error: {e}")

# Run the file processing once
if __name__ == "__main__":
    print("Starting to process the file...")
    process_file()
# Out:
# Starting to process the file...
# Processing file: shakespeare.txt
# Processing line at position 45, content: From fairest creatures we desire increase,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 0
# Sent content at position 45: From fairest creatures we desire increase,
# Updated word count (last 5 words): {'fairest': 1, 'creatures': 1, 'we': 1, 'desire': 1, 'increase': 1}
# Processing line at position 91, content: That thereby beauty's rose might never die,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 1
# Sent content at position 91: That thereby beauty's rose might never die,
# Updated word count (last 5 words): {'s': 1, 'rose': 1, 'might': 1, 'never': 1, 'die': 1}
# Processing line at position 134, content: But as the riper should by time decease,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 2
# Sent content at position 134: But as the riper should by time decease,
# Updated word count (last 5 words): {'riper': 1, 'should': 1, 'by': 1, 'time': 1, 'decease': 1}
# Processing line at position 175, content: His tender heir might bear his memory:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 3
# Sent content at position 175: His tender heir might bear his memory:
# Updated word count (last 5 words): {'his': 2, 'tender': 1, 'heir': 1, 'bear': 1, 'memory': 1}
# Processing line at position 223, content: But thou contracted to thine own bright eyes,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 4
# Sent content at position 223: But thou contracted to thine own bright eyes,
# Updated word count (last 5 words): {'to': 1, 'thine': 1, 'own': 1, 'bright': 1, 'eyes': 1}
# Processing line at position 279, content: Feed'st thy light's flame with self-substantial fuel,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 5
# Sent content at position 279: Feed'st thy light's flame with self-substantial fuel,
# Updated word count (last 5 words): {'flame': 1, 'with': 1, 'self': 1, 'substantial': 1, 'fuel': 1}
# Processing line at position 319, content: Making a famine where abundance lies,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 6
# Sent content at position 319: Making a famine where abundance lies,
# Updated word count (last 5 words): {'a': 1, 'famine': 1, 'where': 1, 'abundance': 1, 'lies': 1}
# Processing line at position 368, content: Thy self thy foe, to thy sweet self too cruel:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 7
# Sent content at position 368: Thy self thy foe, to thy sweet self too cruel:
# Updated word count (last 5 words): {'lies': 1, 'foe': 1, 'sweet': 1, 'too': 1, 'cruel': 1}
# Processing line at position 416, content: Thou that art now the world's fresh ornament,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 8
# Sent content at position 416: Thou that art now the world's fresh ornament,
# Updated word count (last 5 words): {'art': 1, 'now': 1, 'world': 1, 'fresh': 1, 'ornament': 1}
# Processing line at position 455, content: And only herald to the gaudy spring,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 9
# Sent content at position 455: And only herald to the gaudy spring,
# Updated word count (last 5 words): {'and': 1, 'only': 1, 'herald': 1, 'gaudy': 1, 'spring': 1}
# Processing line at position 499, content: Within thine own bud buriest thy content,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 10
# Sent content at position 499: Within thine own bud buriest thy content,
# Updated word count (last 5 words): {'spring': 1, 'within': 1, 'bud': 1, 'buriest': 1, 'content': 1}
# Processing line at position 546, content: And tender churl mak'st waste in niggarding:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 11
# Sent content at position 546: And tender churl mak'st waste in niggarding:
# Updated word count (last 5 words): {'churl': 1, 'mak': 1, 'waste': 1, 'in': 1, 'niggarding': 1}
# Processing line at position 591, content: Pity the world, or else this glutton be,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 12
# Sent content at position 591: Pity the world, or else this glutton be,
# Updated word count (last 5 words): {'or': 1, 'else': 1, 'this': 1, 'glutton': 1, 'be': 1}
# Processing line at position 642, content: To eat the world's due, by the grave and thee.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 13
# Sent content at position 642: To eat the world's due, by the grave and thee.
# Updated word count (last 5 words): {'be': 1, 'eat': 1, 'due': 1, 'grave': 1, 'thee': 1}
# Processing line at position 643, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 14
# Sent content at position 643:
# Updated word count (last 5 words): {'be': 1, 'eat': 1, 'due': 1, 'grave': 1, 'thee': 1}
# Processing line at position 644, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 15
# Sent content at position 644:
# Updated word count (last 5 words): {'be': 1, 'eat': 1, 'due': 1, 'grave': 1, 'thee': 1}
# Processing line at position 667, content: 2
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 16
# Sent content at position 667: 2
# Updated word count (last 5 words): {'eat': 1, 'due': 1, 'grave': 1, 'thee': 1, '2': 1}
# Processing line at position 712, content: When forty winters shall besiege thy brow,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 17
# Sent content at position 712: When forty winters shall besiege thy brow,
# Updated word count (last 5 words): {'forty': 1, 'winters': 1, 'shall': 1, 'besiege': 1, 'brow': 1}
# Processing line at position 759, content: And dig deep trenches in thy beauty's field,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 18
# Sent content at position 759: And dig deep trenches in thy beauty's field,
# Updated word count (last 5 words): {'brow': 1, 'dig': 1, 'deep': 1, 'trenches': 1, 'field': 1}
# Processing line at position 803, content: Thy youth's proud livery so gazed on now,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 19
# Sent content at position 803: Thy youth's proud livery so gazed on now,
# Updated word count (last 5 words): {'proud': 1, 'livery': 1, 'so': 1, 'gazed': 1, 'on': 1}
# Processing line at position 850, content: Will be a tattered weed of small worth held:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 20
# Sent content at position 850: Will be a tattered weed of small worth held:
# Updated word count (last 5 words): {'weed': 1, 'of': 1, 'small': 1, 'worth': 1, 'held': 1}
# Processing line at position 897, content: Then being asked, where all thy beauty lies,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 21
# Sent content at position 897: Then being asked, where all thy beauty lies,
# Updated word count (last 5 words): {'held': 1, 'then': 1, 'being': 1, 'asked': 1, 'all': 1}
# Processing line at position 941, content: Where all the treasure of thy lusty days;
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 22
# Sent content at position 941: Where all the treasure of thy lusty days;
# Updated word count (last 5 words): {'asked': 1, 'all': 2, 'treasure': 1, 'lusty': 1, 'days': 1}
# Processing line at position 985, content: To say within thine own deep sunken eyes,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 23
# Sent content at position 985: To say within thine own deep sunken eyes,
# Updated word count (last 5 words): {'treasure': 1, 'lusty': 1, 'days': 1, 'say': 1, 'sunken': 1}
# Processing line at position 1036, content: Were an all-eating shame, and thriftless praise.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 24
# Sent content at position 1036: Were an all-eating shame, and thriftless praise.
# Updated word count (last 5 words): {'an': 1, 'eating': 1, 'shame': 1, 'thriftless': 1, 'praise': 1}
# Processing line at position 1086, content: How much more praise deserved thy beauty's use,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 25
# Sent content at position 1086: How much more praise deserved thy beauty's use,
# Updated word count (last 5 words): {'how': 1, 'much': 1, 'more': 1, 'deserved': 1, 'use': 1}
# Processing line at position 1136, content: If thou couldst answer 'This fair child of mine
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 26
# Sent content at position 1136: If thou couldst answer 'This fair child of mine
# Updated word count (last 5 words): {'couldst': 1, 'answer': 1, 'fair': 1, 'child': 1, 'mine': 1}
# Processing line at position 1182, content: Shall sum my count, and make my old excuse'
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 27
# Sent content at position 1182: Shall sum my count, and make my old excuse'
# Updated word count (last 5 words): {'my': 2, 'count': 1, 'make': 1, 'old': 1, 'excuse': 1}
# Processing line at position 1224, content: Proving his beauty by succession thine.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 28
# Sent content at position 1224: Proving his beauty by succession thine.
# Updated word count (last 5 words): {'make': 1, 'old': 1, 'excuse': 1, 'proving': 1, 'succession': 1}
# Processing line at position 1272, content: This were to be new made when thou art old,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 29
# Sent content at position 1272: This were to be new made when thou art old,
# Updated word count (last 5 words): {'excuse': 1, 'proving': 1, 'succession': 1, 'new': 1, 'made': 1}
# Processing line at position 1326, content: And see thy blood warm when thou feel'st it cold.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 30
# Sent content at position 1326: And see thy blood warm when thou feel'st it cold.
# Updated word count (last 5 words): {'blood': 1, 'warm': 1, 'feel': 1, 'it': 1, 'cold': 1}
# Processing line at position 1327, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 31
# Sent content at position 1327:
# Updated word count (last 5 words): {'blood': 1, 'warm': 1, 'feel': 1, 'it': 1, 'cold': 1}
# Processing line at position 1328, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 32
# Sent content at position 1328:
# Updated word count (last 5 words): {'blood': 1, 'warm': 1, 'feel': 1, 'it': 1, 'cold': 1}
# Processing line at position 1351, content: 3
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 33
# Sent content at position 1351: 3
# Updated word count (last 5 words): {'warm': 1, 'feel': 1, 'it': 1, 'cold': 1, '3': 1}
# Processing line at position 1403, content: Look in thy glass and tell the face thou viewest,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 34
# Sent content at position 1403: Look in thy glass and tell the face thou viewest,
# Updated word count (last 5 words): {'look': 1, 'glass': 1, 'tell': 1, 'face': 1, 'viewest': 1}
# Processing line at position 1452, content: Now is the time that face should form another,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 35
# Sent content at position 1452: Now is the time that face should form another,
# Updated word count (last 5 words): {'face': 2, 'viewest': 1, 'is': 1, 'form': 1, 'another': 1}
# Processing line at position 1499, content: Whose fresh repair if now thou not renewest,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 36
# Sent content at position 1499: Whose fresh repair if now thou not renewest,
# Updated word count (last 5 words): {'another': 1, 'whose': 1, 'repair': 1, 'not': 1, 'renewest': 1}
# Processing line at position 1551, content: Thou dost beguile the world, unbless some mother.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 37
# Sent content at position 1551: Thou dost beguile the world, unbless some mother.
# Updated word count (last 5 words): {'dost': 1, 'beguile': 1, 'unbless': 1, 'some': 1, 'mother': 1}
# Processing line at position 1597, content: For where is she so fair whose uneared womb
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 38
# Sent content at position 1597: For where is she so fair whose uneared womb
# Updated word count (last 5 words): {'mother': 1, 'for': 1, 'she': 1, 'uneared': 1, 'womb': 1}
# Processing line at position 1638, content: Disdains the tillage of thy husbandry?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 39
# Sent content at position 1638: Disdains the tillage of thy husbandry?
# Updated word count (last 5 words): {'uneared': 1, 'womb': 1, 'disdains': 1, 'tillage': 1, 'husbandry': 1}
# Processing line at position 1679, content: Or who is he so fond will be the tomb,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 40
# Sent content at position 1679: Or who is he so fond will be the tomb,
# Updated word count (last 5 words): {'husbandry': 1, 'who': 1, 'he': 1, 'fond': 1, 'tomb': 1}
# Processing line at position 1717, content: Of his self-love to stop posterity?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 41
# Sent content at position 1717: Of his self-love to stop posterity?
# Updated word count (last 5 words): {'fond': 1, 'tomb': 1, 'love': 1, 'stop': 1, 'posterity': 1}
# Processing line at position 1763, content: Thou art thy mother's glass and she in thee
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 42
# Sent content at position 1763: Thou art thy mother's glass and she in thee
# Updated word count (last 5 words): {'fond': 1, 'tomb': 1, 'love': 1, 'stop': 1, 'posterity': 1}
# Processing line at position 1807, content: Calls back the lovely April of her prime,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 43
# Sent content at position 1807: Calls back the lovely April of her prime,
# Updated word count (last 5 words): {'back': 1, 'lovely': 1, 'april': 1, 'her': 1, 'prime': 1}
# Processing line at position 1857, content: So thou through windows of thine age shalt see,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 44
# Sent content at position 1857: So thou through windows of thine age shalt see,
# Updated word count (last 5 words): {'prime': 1, 'through': 1, 'windows': 1, 'age': 1, 'shalt': 1}
# Processing line at position 1901, content: Despite of wrinkles this thy golden time.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 45
# Sent content at position 1901: Despite of wrinkles this thy golden time.
# Updated word count (last 5 words): {'age': 1, 'shalt': 1, 'despite': 1, 'wrinkles': 1, 'golden': 1}
# Processing line at position 1944, content: But if thou live remembered not to be,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 46
# Sent content at position 1944: But if thou live remembered not to be,
# Updated word count (last 5 words): {'despite': 1, 'wrinkles': 1, 'golden': 1, 'live': 1, 'remembered': 1}
# Processing line at position 1991, content: Die single and thine image dies with thee.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 47
# Sent content at position 1991: Die single and thine image dies with thee.
# Updated word count (last 5 words): {'live': 1, 'remembered': 1, 'single': 1, 'image': 1, 'dies': 1}
# Processing line at position 1992, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 48
# Sent content at position 1992:
# Updated word count (last 5 words): {'live': 1, 'remembered': 1, 'single': 1, 'image': 1, 'dies': 1}
# Processing line at position 1993, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 49
# Sent content at position 1993:
# Updated word count (last 5 words): {'live': 1, 'remembered': 1, 'single': 1, 'image': 1, 'dies': 1}
# Processing line at position 2016, content: 4
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 50
# Sent content at position 2016: 4
# Updated word count (last 5 words): {'remembered': 1, 'single': 1, 'image': 1, 'dies': 1, '4': 1}
# Processing line at position 2060, content: Unthrifty loveliness why dost thou spend,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 51
# Sent content at position 2060: Unthrifty loveliness why dost thou spend,
# Updated word count (last 5 words): {'4': 1, 'unthrifty': 1, 'loveliness': 1, 'why': 1, 'spend': 1}
# Processing line at position 2097, content: Upon thy self thy beauty's legacy?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 52
# Sent content at position 2097: Upon thy self thy beauty's legacy?
# Updated word count (last 5 words): {'loveliness': 1, 'why': 1, 'spend': 1, 'upon': 1, 'legacy': 1}
# Processing line at position 2145, content: Nature's bequest gives nothing but doth lend,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 53
# Sent content at position 2145: Nature's bequest gives nothing but doth lend,
# Updated word count (last 5 words): {'bequest': 1, 'gives': 1, 'nothing': 1, 'doth': 1, 'lend': 1}
# Processing line at position 2192, content: And being frank she lends to those are free:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 54
# Sent content at position 2192: And being frank she lends to those are free:
# Updated word count (last 5 words): {'frank': 1, 'lends': 1, 'those': 1, 'are': 1, 'free': 1}
# Processing line at position 2238, content: Then beauteous niggard why dost thou abuse,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 55
# Sent content at position 2238: Then beauteous niggard why dost thou abuse,
# Updated word count (last 5 words): {'are': 1, 'free': 1, 'beauteous': 1, 'niggard': 1, 'abuse': 1}
# Processing line at position 2282, content: The bounteous largess given thee to give?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 56
# Sent content at position 2282: The bounteous largess given thee to give?
# Updated word count (last 5 words): {'abuse': 1, 'bounteous': 1, 'largess': 1, 'given': 1, 'give': 1}
# Processing line at position 2320, content: Profitless usurer why dost thou use
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 57
# Sent content at position 2320: Profitless usurer why dost thou use
# Updated word count (last 5 words): {'largess': 1, 'given': 1, 'give': 1, 'profitless': 1, 'usurer': 1}
# Processing line at position 2365, content: So great a sum of sums yet canst not live?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 58
# Sent content at position 2365: So great a sum of sums yet canst not live?
# Updated word count (last 5 words): {'usurer': 1, 'great': 1, 'sums': 1, 'yet': 1, 'canst': 1}
# Processing line at position 2407, content: For having traffic with thy self alone,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 59
# Sent content at position 2407: For having traffic with thy self alone,
# Updated word count (last 5 words): {'yet': 1, 'canst': 1, 'having': 1, 'traffic': 1, 'alone': 1}
# Processing line at position 2455, content: Thou of thy self thy sweet self dost deceive,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 60
# Sent content at position 2455: Thou of thy self thy sweet self dost deceive,
# Updated word count (last 5 words): {'canst': 1, 'having': 1, 'traffic': 1, 'alone': 1, 'deceive': 1}
# Processing line at position 2501, content: Then how when nature calls thee to be gone,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 61
# Sent content at position 2501: Then how when nature calls thee to be gone,
# Updated word count (last 5 words): {'having': 1, 'traffic': 1, 'alone': 1, 'deceive': 1, 'gone': 1}
# Processing line at position 2543, content: What acceptable audit canst thou leave?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 62
# Sent content at position 2543: What acceptable audit canst thou leave?
# Updated word count (last 5 words): {'gone': 1, 'what': 1, 'acceptable': 1, 'audit': 1, 'leave': 1}
# Processing line at position 2591, content: Thy unused beauty must be tombed with thee,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 63
# Sent content at position 2591: Thy unused beauty must be tombed with thee,
# Updated word count (last 5 words): {'audit': 1, 'leave': 1, 'unused': 1, 'must': 1, 'tombed': 1}
# Processing line at position 2632, content: Which used lives th' executor to be.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 64
# Sent content at position 2632: Which used lives th' executor to be.
# Updated word count (last 5 words): {'which': 1, 'used': 1, 'lives': 1, 'th': 1, 'executor': 1}
# Processing line at position 2633, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 65
# Sent content at position 2633:
# Updated word count (last 5 words): {'which': 1, 'used': 1, 'lives': 1, 'th': 1, 'executor': 1}
# Processing line at position 2634, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 66
# Sent content at position 2634:
# Updated word count (last 5 words): {'which': 1, 'used': 1, 'lives': 1, 'th': 1, 'executor': 1}
# Processing line at position 2657, content: 5
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 67
# Sent content at position 2657: 5
# Updated word count (last 5 words): {'used': 1, 'lives': 1, 'th': 1, 'executor': 1, '5': 1}
# Processing line at position 2703, content: Those hours that with gentle work did frame
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 68
# Sent content at position 2703: Those hours that with gentle work did frame
# Updated word count (last 5 words): {'hours': 1, 'gentle': 1, 'work': 1, 'did': 1, 'frame': 1}
# Processing line at position 2748, content: The lovely gaze where every eye doth dwell
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 69
# Sent content at position 2748: The lovely gaze where every eye doth dwell
# Updated word count (last 5 words): {'frame': 1, 'gaze': 1, 'every': 1, 'eye': 1, 'dwell': 1}
# Processing line at position 2790, content: Will play the tyrants to the very same,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 70
# Sent content at position 2790: Will play the tyrants to the very same,
# Updated word count (last 5 words): {'dwell': 1, 'play': 1, 'tyrants': 1, 'very': 1, 'same': 1}
# Processing line at position 2833, content: And that unfair which fairly doth excel:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 71
# Sent content at position 2833: And that unfair which fairly doth excel:
# Updated word count (last 5 words): {'very': 1, 'same': 1, 'unfair': 1, 'fairly': 1, 'excel': 1}
# Processing line at position 2874, content: For never-resting time leads summer on
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 72
# Sent content at position 2874: For never-resting time leads summer on
# Updated word count (last 5 words): {'fairly': 1, 'excel': 1, 'resting': 1, 'leads': 1, 'summer': 1}
# Processing line at position 2919, content: To hideous winter and confounds him there,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 73
# Sent content at position 2919: To hideous winter and confounds him there,
# Updated word count (last 5 words): {'hideous': 1, 'winter': 1, 'confounds': 1, 'him': 1, 'there': 1}
# Processing line at position 2973, content: Sap checked with frost and lusty leaves quite gone,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 74
# Sent content at position 2973: Sap checked with frost and lusty leaves quite gone,
# Updated word count (last 5 words): {'sap': 1, 'checked': 1, 'frost': 1, 'leaves': 1, 'quite': 1}
# Processing line at position 3020, content: Beauty o'er-snowed and bareness every where:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 75
# Sent content at position 3020: Beauty o'er-snowed and bareness every where:
# Updated word count (last 5 words): {'quite': 1, 'o': 1, 'er': 1, 'snowed': 1, 'bareness': 1}
# Processing line at position 3063, content: Then were not summer's distillation left
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 76
# Sent content at position 3063: Then were not summer's distillation left
# Updated word count (last 5 words): {'er': 1, 'snowed': 1, 'bareness': 1, 'distillation': 1, 'left': 1}
# Processing line at position 3107, content: A liquid prisoner pent in walls of glass,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 77
# Sent content at position 3107: A liquid prisoner pent in walls of glass,
# Updated word count (last 5 words): {'left': 1, 'liquid': 1, 'prisoner': 1, 'pent': 1, 'walls': 1}
# Processing line at position 3150, content: Beauty's effect with beauty were bereft,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 78
# Sent content at position 3150: Beauty's effect with beauty were bereft,
# Updated word count (last 5 words): {'prisoner': 1, 'pent': 1, 'walls': 1, 'effect': 1, 'bereft': 1}
# Processing line at position 3191, content: Nor it nor no remembrance what it was.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 79
# Sent content at position 3191: Nor it nor no remembrance what it was.
# Updated word count (last 5 words): {'bereft': 1, 'nor': 2, 'no': 1, 'remembrance': 1, 'was': 1}
# Processing line at position 3247, content: But flowers distilled though they with winter meet,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 80
# Sent content at position 3247: But flowers distilled though they with winter meet,
# Updated word count (last 5 words): {'flowers': 1, 'distilled': 1, 'though': 1, 'they': 1, 'meet': 1}
# Processing line at position 3308, content: Leese but their show, their substance still lives sweet.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 81
# Sent content at position 3308: Leese but their show, their substance still lives sweet.
# Updated word count (last 5 words): {'leese': 1, 'their': 2, 'show': 1, 'substance': 1, 'still': 1}
# Processing line at position 3309, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 82
# Sent content at position 3309:
# Updated word count (last 5 words): {'leese': 1, 'their': 2, 'show': 1, 'substance': 1, 'still': 1}
# Processing line at position 3310, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 83
# Sent content at position 3310:
# Updated word count (last 5 words): {'leese': 1, 'their': 2, 'show': 1, 'substance': 1, 'still': 1}
# Processing line at position 3333, content: 6
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 84
# Sent content at position 3333: 6
# Updated word count (last 5 words): {'their': 2, 'show': 1, 'substance': 1, 'still': 1, '6': 1}
# Processing line at position 3377, content: Then let not winter's ragged hand deface,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 85
# Sent content at position 3377: Then let not winter's ragged hand deface,
# Updated word count (last 5 words): {'6': 1, 'let': 1, 'ragged': 1, 'hand': 1, 'deface': 1}
# Processing line at position 3421, content: In thee thy summer ere thou be distilled:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 86
# Sent content at position 3421: In thee thy summer ere thou be distilled:
# Updated word count (last 5 words): {'let': 1, 'ragged': 1, 'hand': 1, 'deface': 1, 'ere': 1}
# Processing line at position 3471, content: Make sweet some vial; treasure thou some place,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 87
# Sent content at position 3471: Make sweet some vial; treasure thou some place,
# Updated word count (last 5 words): {'hand': 1, 'deface': 1, 'ere': 1, 'vial': 1, 'place': 1}
# Processing line at position 3519, content: With beauty's treasure ere it be self-killed:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 88
# Sent content at position 3519: With beauty's treasure ere it be self-killed:
# Updated word count (last 5 words): {'deface': 1, 'ere': 2, 'vial': 1, 'place': 1, 'killed': 1}
# Processing line at position 3554, content: That use is not forbidden usury,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 89
# Sent content at position 3554: That use is not forbidden usury,
# Updated word count (last 5 words): {'vial': 1, 'place': 1, 'killed': 1, 'forbidden': 1, 'usury': 1}
# Processing line at position 3603, content: Which happies those that pay the willing loan;
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 90
# Sent content at position 3603: Which happies those that pay the willing loan;
# Updated word count (last 5 words): {'usury': 1, 'happies': 1, 'pay': 1, 'willing': 1, 'loan': 1}
# Processing line at position 3648, content: That's for thy self to breed another thee,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 91
# Sent content at position 3648: That's for thy self to breed another thee,
# Updated word count (last 5 words): {'happies': 1, 'pay': 1, 'willing': 1, 'loan': 1, 'breed': 1}
# Processing line at position 3690, content: Or ten times happier be it ten for one,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 92
# Sent content at position 3690: Or ten times happier be it ten for one,
# Updated word count (last 5 words): {'breed': 1, 'ten': 2, 'times': 1, 'happier': 1, 'one': 1}
# Processing line at position 3739, content: Ten times thy self were happier than thou art,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 93
# Sent content at position 3739: Ten times thy self were happier than thou art,
# Updated word count (last 5 words): {'ten': 3, 'times': 2, 'happier': 2, 'one': 1, 'than': 1}
# Processing line at position 3783, content: If ten of thine ten times refigured thee:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 94
# Sent content at position 3783: If ten of thine ten times refigured thee:
# Updated word count (last 5 words): {'times': 3, 'happier': 2, 'one': 1, 'than': 1, 'refigured': 1}
# Processing line at position 3835, content: Then what could death do if thou shouldst depart,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 95
# Sent content at position 3835: Then what could death do if thou shouldst depart,
# Updated word count (last 5 words): {'could': 1, 'death': 1, 'do': 1, 'shouldst': 1, 'depart': 1}
# Processing line at position 3871, content: Leaving thee living in posterity?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 96
# Sent content at position 3871: Leaving thee living in posterity?
# Updated word count (last 5 words): {'do': 1, 'shouldst': 1, 'depart': 1, 'leaving': 1, 'living': 1}
# Processing line at position 3922, content: Be not self-willed for thou art much too fair,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 97
# Sent content at position 3922: Be not self-willed for thou art much too fair,
# Updated word count (last 5 words): {'shouldst': 1, 'depart': 1, 'leaving': 1, 'living': 1, 'willed': 1}
# Processing line at position 3976, content: To be death's conquest and make worms thine heir.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 98
# Sent content at position 3976: To be death's conquest and make worms thine heir.
# Updated word count (last 5 words): {'leaving': 1, 'living': 1, 'willed': 1, 'conquest': 1, 'worms': 1}
# Processing line at position 3977, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 99
# Sent content at position 3977:
# Updated word count (last 5 words): {'leaving': 1, 'living': 1, 'willed': 1, 'conquest': 1, 'worms': 1}
# Processing line at position 3978, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 100
# Sent content at position 3978:
# Updated word count (last 5 words): {'leaving': 1, 'living': 1, 'willed': 1, 'conquest': 1, 'worms': 1}
# Processing line at position 4001, content: 7
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 101
# Sent content at position 4001: 7
# Updated word count (last 5 words): {'living': 1, 'willed': 1, 'conquest': 1, 'worms': 1, '7': 1}
# Processing line at position 4044, content: Lo in the orient when the gracious light
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 102
# Sent content at position 4044: Lo in the orient when the gracious light
# Updated word count (last 5 words): {'worms': 1, '7': 1, 'lo': 1, 'orient': 1, 'gracious': 1}
# Processing line at position 4088, content: Lifts up his burning head, each under eye
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 103
# Sent content at position 4088: Lifts up his burning head, each under eye
# Updated word count (last 5 words): {'up': 1, 'burning': 1, 'head': 1, 'each': 1, 'under': 1}
# Processing line at position 4130, content: Doth homage to his new-appearing sight,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 104
# Sent content at position 4130: Doth homage to his new-appearing sight,
# Updated word count (last 5 words): {'each': 1, 'under': 1, 'homage': 1, 'appearing': 1, 'sight': 1}
# Processing line at position 4171, content: Serving with looks his sacred majesty,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 105
# Sent content at position 4171: Serving with looks his sacred majesty,
# Updated word count (last 5 words): {'sight': 1, 'serving': 1, 'looks': 1, 'sacred': 1, 'majesty': 1}
# Processing line at position 4220, content: And having climbed the steep-up heavenly hill,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 106
# Sent content at position 4220: And having climbed the steep-up heavenly hill,
# Updated word count (last 5 words): {'majesty': 1, 'climbed': 1, 'steep': 1, 'heavenly': 1, 'hill': 1}
# Processing line at position 4265, content: Resembling strong youth in his middle age,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 107
# Sent content at position 4265: Resembling strong youth in his middle age,
# Updated word count (last 5 words): {'heavenly': 1, 'hill': 1, 'resembling': 1, 'strong': 1, 'middle': 1}
# Processing line at position 4308, content: Yet mortal looks adore his beauty still,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 108
# Sent content at position 4308: Yet mortal looks adore his beauty still,
# Updated word count (last 5 words): {'resembling': 1, 'strong': 1, 'middle': 1, 'mortal': 1, 'adore': 1}
# Processing line at position 4346, content: Attending on his golden pilgrimage:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 109
# Sent content at position 4346: Attending on his golden pilgrimage:
# Updated word count (last 5 words): {'middle': 1, 'mortal': 1, 'adore': 1, 'attending': 1, 'pilgrimage': 1}
# Processing line at position 4393, content: But when from highmost pitch with weary car,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 110
# Sent content at position 4393: But when from highmost pitch with weary car,
# Updated word count (last 5 words): {'pilgrimage': 1, 'highmost': 1, 'pitch': 1, 'weary': 1, 'car': 1}
# Processing line at position 4436, content: Like feeble age he reeleth from the day,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 111
# Sent content at position 4436: Like feeble age he reeleth from the day,
# Updated word count (last 5 words): {'car': 1, 'like': 1, 'feeble': 1, 'reeleth': 1, 'day': 1}
# Processing line at position 4480, content: The eyes (fore duteous) now converted are
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 112
# Sent content at position 4480: The eyes (fore duteous) now converted are
# Updated word count (last 5 words): {'reeleth': 1, 'day': 1, 'fore': 1, 'duteous': 1, 'converted': 1}
# Processing line at position 4523, content: From his low tract and look another way:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 113
# Sent content at position 4523: From his low tract and look another way:
# Updated word count (last 5 words): {'duteous': 1, 'converted': 1, 'low': 1, 'tract': 1, 'way': 1}
# Processing line at position 4568, content: So thou, thy self out-going in thy noon:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 114
# Sent content at position 4568: So thou, thy self out-going in thy noon:
# Updated word count (last 5 words): {'tract': 1, 'way': 1, 'out': 1, 'going': 1, 'noon': 1}
# Processing line at position 4613, content: Unlooked on diest unless thou get a son.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 115
# Sent content at position 4613: Unlooked on diest unless thou get a son.
# Updated word count (last 5 words): {'unlooked': 1, 'diest': 1, 'unless': 1, 'get': 1, 'son': 1}
# Processing line at position 4614, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 116
# Sent content at position 4614:
# Updated word count (last 5 words): {'unlooked': 1, 'diest': 1, 'unless': 1, 'get': 1, 'son': 1}
# Processing line at position 4615, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 117
# Sent content at position 4615:
# Updated word count (last 5 words): {'unlooked': 1, 'diest': 1, 'unless': 1, 'get': 1, 'son': 1}
# Processing line at position 4638, content: 8
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 118
# Sent content at position 4638: 8
# Updated word count (last 5 words): {'diest': 1, 'unless': 1, 'get': 1, 'son': 1, '8': 1}
# Processing line at position 4685, content: Music to hear, why hear'st thou music sadly?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 119
# Sent content at position 4685: Music to hear, why hear'st thou music sadly?
# Updated word count (last 5 words): {'son': 1, '8': 1, 'music': 2, 'hear': 2, 'sadly': 1}
# Processing line at position 4736, content: Sweets with sweets war not, joy delights in joy:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 120
# Sent content at position 4736: Sweets with sweets war not, joy delights in joy:
# Updated word count (last 5 words): {'sadly': 1, 'sweets': 2, 'war': 1, 'joy': 2, 'delights': 1}
# Processing line at position 4792, content: Why lov'st thou that which thou receiv'st not gladly,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 121
# Sent content at position 4792: Why lov'st thou that which thou receiv'st not gladly,
# Updated word count (last 5 words): {'joy': 2, 'delights': 1, 'lov': 1, 'receiv': 1, 'gladly': 1}
# Processing line at position 4839, content: Or else receiv'st with pleasure thine annoy?
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 122
# Sent content at position 4839: Or else receiv'st with pleasure thine annoy?
# Updated word count (last 5 words): {'lov': 1, 'receiv': 2, 'gladly': 1, 'pleasure': 1, 'annoy': 1}
# Processing line at position 4883, content: If the true concord of well-tuned sounds,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 123
# Sent content at position 4883: If the true concord of well-tuned sounds,
# Updated word count (last 5 words): {'true': 1, 'concord': 1, 'well': 1, 'tuned': 1, 'sounds': 1}
# Processing line at position 4924, content: By unions married do offend thine ear,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 124
# Sent content at position 4924: By unions married do offend thine ear,
# Updated word count (last 5 words): {'sounds': 1, 'unions': 1, 'married': 1, 'offend': 1, 'ear': 1}
# Processing line at position 4972, content: They do but sweetly chide thee, who confounds
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 125
# Sent content at position 4972: They do but sweetly chide thee, who confounds
# Updated word count (last 5 words): {'married': 1, 'offend': 1, 'ear': 1, 'sweetly': 1, 'chide': 1}
# Processing line at position 5023, content: In singleness the parts that thou shouldst bear:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 126
# Sent content at position 5023: In singleness the parts that thou shouldst bear:
# Updated word count (last 5 words): {'ear': 1, 'sweetly': 1, 'chide': 1, 'singleness': 1, 'parts': 1}
# Processing line at position 5071, content: Mark how one string sweet husband to another,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 127
# Sent content at position 5071: Mark how one string sweet husband to another,
# Updated word count (last 5 words): {'singleness': 1, 'parts': 1, 'mark': 1, 'string': 1, 'husband': 1}
# Processing line at position 5114, content: Strikes each in each by mutual ordering;
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 128
# Sent content at position 5114: Strikes each in each by mutual ordering;
# Updated word count (last 5 words): {'string': 1, 'husband': 1, 'strikes': 1, 'mutual': 1, 'ordering': 1}
# Processing line at position 5162, content: Resembling sire, and child, and happy mother,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 129
# Sent content at position 5162: Resembling sire, and child, and happy mother,
# ...
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 365
# Sent content at position 14576: O therefore love be of thyself so wary,
# Updated word count (last 5 words): {'breast': 1, 'elder': 1, 'therefore': 1, 'thyself': 1, 'wary': 1}
# Processing line at position 14619, content: As I not for my self, but for thee will,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 366
# Sent content at position 14619: As I not for my self, but for thee will,
# Updated word count (last 5 words): {'breast': 1, 'elder': 1, 'therefore': 1, 'thyself': 1, 'wary': 1}
# Processing line at position 14666, content: Bearing thy heart which I will keep so chary
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 367
# Sent content at position 14666: Bearing thy heart which I will keep so chary
# Updated word count (last 5 words): {'therefore': 1, 'thyself': 1, 'wary': 1, 'bearing': 1, 'chary': 1}
# Processing line at position 14710, content: As tender nurse her babe from faring ill.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 368
# Sent content at position 14710: As tender nurse her babe from faring ill.
# Updated word count (last 5 words): {'chary': 1, 'nurse': 1, 'babe': 1, 'faring': 1, 'ill': 1}
# Processing line at position 14759, content: Presume not on thy heart when mine is slain,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 369
# Sent content at position 14759: Presume not on thy heart when mine is slain,
# Updated word count (last 5 words): {'babe': 1, 'faring': 1, 'ill': 1, 'presume': 1, 'slain': 1}
# Processing line at position 14808, content: Thou gav'st me thine not to give back again.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 370
# Sent content at position 14808: Thou gav'st me thine not to give back again.
# Updated word count (last 5 words): {'faring': 1, 'ill': 1, 'presume': 1, 'slain': 1, 'gav': 1}
# Processing line at position 14809, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 371
# Sent content at position 14809:
# Updated word count (last 5 words): {'faring': 1, 'ill': 1, 'presume': 1, 'slain': 1, 'gav': 1}
# Processing line at position 14810, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 372
# Sent content at position 14810:
# Updated word count (last 5 words): {'faring': 1, 'ill': 1, 'presume': 1, 'slain': 1, 'gav': 1}
# Processing line at position 14834, content: 23
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 373
# Sent content at position 14834: 23
# Updated word count (last 5 words): {'ill': 1, 'presume': 1, 'slain': 1, 'gav': 1, '23': 1}
# Processing line at position 14872, content: As an unperfect actor on the stage,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 374
# Sent content at position 14872: As an unperfect actor on the stage,
# Updated word count (last 5 words): {'slain': 1, 'gav': 1, '23': 1, 'unperfect': 1, 'actor': 1}
# Processing line at position 14916, content: Who with his fear is put beside his part,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 375
# Sent content at position 14916: Who with his fear is put beside his part,
# Updated word count (last 5 words): {'unperfect': 1, 'actor': 1, 'put': 1, 'beside': 1, 'part': 1}
# Processing line at position 14967, content: Or some fierce thing replete with too much rage,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 376
# Sent content at position 14967: Or some fierce thing replete with too much rage,
# Updated word count (last 5 words): {'actor': 1, 'put': 1, 'beside': 1, 'part': 1, 'replete': 1}
# Processing line at position 15019, content: Whose strength's abundance weakens his own heart;
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 377
# Sent content at position 15019: Whose strength's abundance weakens his own heart;
# Updated word count (last 5 words): {'beside': 1, 'part': 1, 'replete': 1, 'strength': 1, 'weakens': 1}
# Processing line at position 15060, content: So I for fear of trust, forget to say,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 378
# Sent content at position 15060: So I for fear of trust, forget to say,
# Updated word count (last 5 words): {'replete': 1, 'strength': 1, 'weakens': 1, 'trust': 1, 'forget': 1}
# Processing line at position 15099, content: The perfect ceremony of love's rite,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 379
# Sent content at position 15099: The perfect ceremony of love's rite,
# Updated word count (last 5 words): {'trust': 1, 'forget': 1, 'perfect': 1, 'ceremony': 1, 'rite': 1}
# Processing line at position 15148, content: And in mine own love's strength seem to decay,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 380
# Sent content at position 15148: And in mine own love's strength seem to decay,
# Updated word count (last 5 words): {'forget': 1, 'perfect': 1, 'ceremony': 1, 'rite': 1, 'seem': 1}
# Processing line at position 15201, content: O'ercharged with burthen of mine own love's might:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 381
# Sent content at position 15201: O'ercharged with burthen of mine own love's might:
# Updated word count (last 5 words): {'ceremony': 1, 'rite': 1, 'seem': 1, 'ercharged': 1, 'burthen': 1}
# Processing line at position 15241, content: O let my looks be then the eloquence,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 382
# Sent content at position 15241: O let my looks be then the eloquence,
# Updated word count (last 5 words): {'rite': 1, 'seem': 1, 'ercharged': 1, 'burthen': 1, 'eloquence': 1}
# Processing line at position 15285, content: And dumb presagers of my speaking breast,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 383
# Sent content at position 15285: And dumb presagers of my speaking breast,
# Updated word count (last 5 words): {'burthen': 1, 'eloquence': 1, 'dumb': 1, 'presagers': 1, 'speaking': 1}
# Processing line at position 15332, content: Who plead for love, and look for recompense,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 384
# Sent content at position 15332: Who plead for love, and look for recompense,
# Updated word count (last 5 words): {'dumb': 1, 'presagers': 1, 'speaking': 1, 'plead': 1, 'recompense': 1}
# Processing line at position 15387, content: More than that tongue that more hath more expressed.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 385
# Sent content at position 15387: More than that tongue that more hath more expressed.
# Updated word count (last 5 words): {'presagers': 1, 'speaking': 1, 'plead': 1, 'recompense': 1, 'expressed': 1}
# Processing line at position 15435, content: O learn to read what silent love hath writ,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 386
# Sent content at position 15435: O learn to read what silent love hath writ,
# Updated word count (last 5 words): {'recompense': 1, 'expressed': 1, 'learn': 1, 'silent': 1, 'writ': 1}
# Processing line at position 15485, content: To hear with eyes belongs to love's fine wit.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 387
# Sent content at position 15485: To hear with eyes belongs to love's fine wit.
# Updated word count (last 5 words): {'silent': 1, 'writ': 1, 'belongs': 1, 'fine': 1, 'wit': 1}
# Processing line at position 15486, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 388
# Sent content at position 15486:
# Updated word count (last 5 words): {'silent': 1, 'writ': 1, 'belongs': 1, 'fine': 1, 'wit': 1}
# Processing line at position 15487, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 389
# Sent content at position 15487:
# Updated word count (last 5 words): {'silent': 1, 'writ': 1, 'belongs': 1, 'fine': 1, 'wit': 1}
# Processing line at position 15511, content: 24
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 390
# Sent content at position 15511: 24
# Updated word count (last 5 words): {'writ': 1, 'belongs': 1, 'fine': 1, 'wit': 1, '24': 1}
# Processing line at position 15564, content: Mine eye hath played the painter and hath stelled,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 391
# Sent content at position 15564: Mine eye hath played the painter and hath stelled,
# Updated word count (last 5 words): {'wit': 1, '24': 1, 'played': 1, 'painter': 1, 'stelled': 1}
# Processing line at position 15606, content: Thy beauty's form in table of my heart,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 392
# Sent content at position 15606: Thy beauty's form in table of my heart,
# Updated word count (last 5 words): {'24': 1, 'played': 1, 'painter': 1, 'stelled': 1, 'table': 1}
# Processing line at position 15648, content: My body is the frame wherein 'tis held,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 393
# Sent content at position 15648: My body is the frame wherein 'tis held,
# Updated word count (last 5 words): {'stelled': 1, 'table': 1, 'body': 1, 'wherein': 1, 'tis': 1}
# Processing line at position 15692, content: And perspective it is best painter's art.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 394
# Sent content at position 15692: And perspective it is best painter's art.
# Updated word count (last 5 words): {'table': 1, 'body': 1, 'wherein': 1, 'tis': 1, 'perspective': 1}
# Processing line at position 15742, content: For through the painter must you see his skill,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 395
# Sent content at position 15742: For through the painter must you see his skill,
# Updated word count (last 5 words): {'table': 1, 'body': 1, 'wherein': 1, 'tis': 1, 'perspective': 1}
# Processing line at position 15789, content: To find where your true image pictured lies,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 396
# Sent content at position 15789: To find where your true image pictured lies,
# Updated word count (last 5 words): {'body': 1, 'wherein': 1, 'tis': 1, 'perspective': 1, 'pictured': 1}
# Processing line at position 15834, content: Which in my bosom's shop is hanging still,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 397
# Sent content at position 15834: Which in my bosom's shop is hanging still,
# Updated word count (last 5 words): {'tis': 1, 'perspective': 1, 'pictured': 1, 'shop': 1, 'hanging': 1}
# Processing line at position 15882, content: That hath his windows glazed with thine eyes:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 398
# Sent content at position 15882: That hath his windows glazed with thine eyes:
# Updated word count (last 5 words): {'perspective': 1, 'pictured': 1, 'shop': 1, 'hanging': 1, 'glazed': 1}
# Processing line at position 15933, content: Now see what good turns eyes for eyes have done,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 399
# Sent content at position 15933: Now see what good turns eyes for eyes have done,
# Updated word count (last 5 words): {'shop': 1, 'hanging': 1, 'glazed': 1, 'turns': 1, 'done': 1}
# Processing line at position 15984, content: Mine eyes have drawn thy shape, and thine for me
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 400
# Sent content at position 15984: Mine eyes have drawn thy shape, and thine for me
# Updated word count (last 5 words): {'shop': 1, 'hanging': 1, 'glazed': 1, 'turns': 1, 'done': 1}
# Processing line at position 16034, content: Are windows to my breast, where-through the sun
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 401
# Sent content at position 16034: Are windows to my breast, where-through the sun
# Updated word count (last 5 words): {'shop': 1, 'hanging': 1, 'glazed': 1, 'turns': 1, 'done': 1}
# Processing line at position 16079, content: Delights to peep, to gaze therein on thee;
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 402
# Sent content at position 16079: Delights to peep, to gaze therein on thee;
# Updated word count (last 5 words): {'glazed': 1, 'turns': 1, 'done': 1, 'peep': 1, 'therein': 1}
# Processing line at position 16130, content: Yet eyes this cunning want to grace their art,
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 403
# Sent content at position 16130: Yet eyes this cunning want to grace their art,
# Updated word count (last 5 words): {'peep': 1, 'therein': 1, 'cunning': 1, 'want': 1, 'grace': 1}
# Processing line at position 16183, content: They draw but what they see, know not the heart.
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 404
# Sent content at position 16183: They draw but what they see, know not the heart.
# Updated word count (last 5 words): {'peep': 1, 'therein': 1, 'cunning': 1, 'want': 1, 'grace': 1}
# Processing line at position 16184, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817A40>] at offset 405
# Sent content at position 16184:
# Updated word count (last 5 words): {'peep': 1, 'therein': 1, 'cunning': 1, 'want': 1, 'grace': 1}
# Processing line at position 16185, content:
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817B40>] at offset 406
# Sent content at position 16185:
# Updated word count (last 5 words): {'peep': 1, 'therein': 1, 'cunning': 1, 'want': 1, 'grace': 1}
# Processing line at position 16209, content: 25
# Message delivered to file-streaming [<built-in method partition of cimpl.Message object at 0x000001CD84817BC0>] at offset 407
# Sent content at position 16209: 25
# Updated word count (last 5 words): {'therein': 1, 'cunning': 1, 'want': 1, 'grace': 1, '25': 1}
