# %%
import time
import threading
from confluent_kafka import Consumer, KafkaException
from collections import Counter

# Initialize global variables
word_count = Counter()
total_chars = 0
processed_messages = False  # Flag to check if all messages are processed

# Kafka consumer configuration
conf = {
    'bootstrap.servers': 'localhost:9092',  # Replace with your Kafka broker address
    'group.id': 'file-streaming-consumer-group',  # Consumer group ID
    'auto.offset.reset': 'earliest',  # Start reading from the earliest message
}

consumer = Consumer(conf)

# Function to process each message received from Kafka
def process_message(message):
    global total_chars

    # Log receipt of the message
    print("Received message...")

    # Check if message value is None
    if message.value() is None:
        print("Received a message with no value. Skipping...")
        return

    line = message.value().decode('utf-8')
    print(f"Decoded line: {line.strip()}")  # Log the decoded message

    # Handle cases where message.key() is None
    cursor_pos = message.key().decode('utf-8') if message.key() is not None else "No Cursor Position"
    print(f"Cursor position: {cursor_pos}")  # Log the cursor position

    # Update total character count
    total_chars += len(line)
    print(f"Updated total character count: {total_chars}")

    # Track word occurrences
    words = line.split()  # Split line into words
    print(f"Words in the line: {words}")

    for word in words:
        word = word.lower()  # Normalize to lowercase
        word_count[word] += 1

    # Log the current word count state
    print(f"Current word count (last 5 words): {dict(list(word_count.items())[-5:])}")

# Function to track and display word frequency in real-time
def track_word_frequency():
    while True:
        if word_count:
            sorted_words = word_count.most_common(5)  # Get the top 5 most frequent words
            print("\nTop 5 most frequent words:")
            for word, count in sorted_words:
                print(f"{word}: {count}")
        time.sleep(5)  # Update the statistics every 5 seconds

# Consumer loop to continuously poll Kafka for messages
def consume_messages():
    global processed_messages
    try:
        consumer.subscribe(['file-streaming'])  # Subscribe to the 'file-streaming' topic
        print("Subscribed to topic 'file-streaming'...")

        while True:
            msg = consumer.poll(timeout=1.0)  # Wait for messages (1 second timeout)

            if msg is None:  # No message received
                if processed_messages:  # If messages have been processed, stop consuming
                    print("All messages processed, closing consumer...")
                    break
                print("No message received, continuing to poll...")
                continue
            elif msg.error():  # Handle any Kafka error
                print(f"Error received: {msg.error()}")
                raise KafkaException(msg.error())
            else:
                print("Processing message...")
                process_message(msg)

    except KeyboardInterrupt:
        print("Consumer stopped by user.")

    finally:
        processed_messages = True
        consumer.close()  # Close the consumer when done

# Start the Kafka consumer and track word frequency in the background
def start_consumer():
    print("Starting the consumer...")

    # Start word frequency tracking in a separate thread
    thread = threading.Thread(target=track_word_frequency)
    thread.daemon = True  # Allow thread to exit when the program terminates
    thread.start()

    # Start consuming Kafka messages
    consumer_thread = threading.Thread(target=consume_messages)
    consumer_thread.daemon = True  # Allow thread to exit when the program terminates
    consumer_thread.start()

# Start the consumer
if __name__ == "__main__":
    print("Starting Kafka consumer...")
    start_consumer()

    # Run a loop to keep the main thread alive while the consumer is running
    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        print("Consumer stopped.")
    finally:
        if not processed_messages:
            consumer.close()  # Properly close the consumer when done
# Out:
# Starting Kafka consumer...
# Starting the consumer...
# Subscribed to topic 'file-streaming'...
# No message received, continuing to poll...
# No message received, continuing to poll...
# No message received, continuing to poll...
# Processing message...
# Received message...
# Decoded line: From fairest creatures we desire increase,
# Cursor position: 45
# Updated total character count: 45
# Words in the line: ['From', 'fairest', 'creatures', 'we', 'desire', 'increase,']
# Current word count (last 5 words): {'fairest': 1, 'creatures': 1, 'we': 1, 'desire': 1, 'increase,': 1}
# Processing message...
# Received message...
# Decoded line: That thereby beauty's rose might never die,
# Cursor position: 91
# Updated total character count: 91
# Words in the line: ['That', 'thereby', "beauty's", 'rose', 'might', 'never', 'die,']
# Current word count (last 5 words): {"beauty's": 1, 'rose': 1, 'might': 1, 'never': 1, 'die,': 1}
# Processing message...
# Received message...
# Decoded line: But as the riper should by time decease,
# Cursor position: 134
# Updated total character count: 134
# Words in the line: ['But', 'as', 'the', 'riper', 'should', 'by', 'time', 'decease,']
# Current word count (last 5 words): {'riper': 1, 'should': 1, 'by': 1, 'time': 1, 'decease,': 1}
# Processing message...
# Received message...
# Decoded line: His tender heir might bear his memory:
# Cursor position: 175
# Updated total character count: 175
# Words in the line: ['His', 'tender', 'heir', 'might', 'bear', 'his', 'memory:']
# Current word count (last 5 words): {'his': 2, 'tender': 1, 'heir': 1, 'bear': 1, 'memory:': 1}
# Processing message...
# Received message...
# Decoded line: But thou contracted to thine own bright eyes,
# Cursor position: 223
# Updated total character count: 223
# Words in the line: ['But', 'thou', 'contracted', 'to', 'thine', 'own', 'bright', 'eyes,']
# Current word count (last 5 words): {'to': 1, 'thine': 1, 'own': 1, 'bright': 1, 'eyes,': 1}
# Processing message...
# Received message...
# Decoded line: Feed'st thy light's flame with self-substantial fuel,
# Cursor position: 279
# Updated total character count: 279
# Words in the line: ["Feed'st", 'thy', "light's", 'flame', 'with', 'self-substantial', 'fuel,']
# Current word count (last 5 words): {"light's": 1, 'flame': 1, 'with': 1, 'self-substantial': 1, 'fuel,': 1}
# Processing message...
# Received message...
# Decoded line: Making a famine where abundance lies,
# Cursor position: 319
# Updated total character count: 319
# Words in the line: ['Making', 'a', 'famine', 'where', 'abundance', 'lies,']
# Current word count (last 5 words): {'a': 1, 'famine': 1, 'where': 1, 'abundance': 1, 'lies,': 1}
# Processing message...
# Received message...
# Decoded line: Thy self thy foe, to thy sweet self too cruel:
# Cursor position: 368
# Updated total character count: 368
# Words in the line: ['Thy', 'self', 'thy', 'foe,', 'to', 'thy', 'sweet', 'self', 'too', 'cruel:']
# Current word count (last 5 words): {'self': 2, 'foe,': 1, 'sweet': 1, 'too': 1, 'cruel:': 1}
# Processing message...
# Received message...
# Decoded line: Thou that art now the world's fresh ornament,
# Cursor position: 416
# Updated total character count: 416
# Words in the line: ['Thou', 'that', 'art', 'now', 'the', "world's", 'fresh', 'ornament,']
# Current word count (last 5 words): {'art': 1, 'now': 1, "world's": 1, 'fresh': 1, 'ornament,': 1}
# Processing message...
# Received message...
# Decoded line: And only herald to the gaudy spring,
# Cursor position: 455
# Updated total character count: 455
# Words in the line: ['And', 'only', 'herald', 'to', 'the', 'gaudy', 'spring,']
# Current word count (last 5 words): {'and': 1, 'only': 1, 'herald': 1, 'gaudy': 1, 'spring,': 1}
# Processing message...
# Received message...
# Decoded line: Within thine own bud buriest thy content,
# Cursor position: 499
# Updated total character count: 499
# Words in the line: ['Within', 'thine', 'own', 'bud', 'buriest', 'thy', 'content,']
# Current word count (last 5 words): {'spring,': 1, 'within': 1, 'bud': 1, 'buriest': 1, 'content,': 1}
# Processing message...
# Received message...
# Decoded line: And tender churl mak'st waste in niggarding:
# Cursor position: 546
# Updated total character count: 546
# Words in the line: ['And', 'tender', 'churl', "mak'st", 'waste', 'in', 'niggarding:']
# Current word count (last 5 words): {'churl': 1, "mak'st": 1, 'waste': 1, 'in': 1, 'niggarding:': 1}
# Processing message...
# Received message...
# Decoded line: Pity the world, or else this glutton be,
# Cursor position: 591
# Updated total character count: 591
# Words in the line: ['Pity', 'the', 'world,', 'or', 'else', 'this', 'glutton', 'be,']
# Current word count (last 5 words): {'or': 1, 'else': 1, 'this': 1, 'glutton': 1, 'be,': 1}
# Processing message...
# Received message...
# Decoded line: To eat the world's due, by the grave and thee.
# Cursor position: 642
# Updated total character count: 642
# Words in the line: ['To', 'eat', 'the', "world's", 'due,', 'by', 'the', 'grave', 'and', 'thee.']
# Current word count (last 5 words): {'be,': 1, 'eat': 1, 'due,': 1, 'grave': 1, 'thee.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 643
# Updated total character count: 643
# Words in the line: []
# Current word count (last 5 words): {'be,': 1, 'eat': 1, 'due,': 1, 'grave': 1, 'thee.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 644
# Updated total character count: 644
# Words in the line: []
# Current word count (last 5 words): {'be,': 1, 'eat': 1, 'due,': 1, 'grave': 1, 'thee.': 1}
# Processing message...
# Received message...
# Decoded line: 2
# Cursor position: 667
# Updated total character count: 667
# Words in the line: ['2']
# Current word count (last 5 words): {'eat': 1, 'due,': 1, 'grave': 1, 'thee.': 1, '2': 1}
# Processing message...
# Received message...
# Decoded line: When forty winters shall besiege thy brow,
# Cursor position: 712
# Updated total character count: 712
# Words in the line: ['When', 'forty', 'winters', 'shall', 'besiege', 'thy', 'brow,']
# Current word count (last 5 words): {'forty': 1, 'winters': 1, 'shall': 1, 'besiege': 1, 'brow,': 1}
# Processing message...
# Received message...
# Decoded line: And dig deep trenches in thy beauty's field,
# Cursor position: 759
# Updated total character count: 759
# Words in the line: ['And', 'dig', 'deep', 'trenches', 'in', 'thy', "beauty's", 'field,']
# Current word count (last 5 words): {'brow,': 1, 'dig': 1, 'deep': 1, 'trenches': 1, 'field,': 1}
# Processing message...
# Received message...
# Decoded line: Thy youth's proud livery so gazed on now,
# Cursor position: 803
# Updated total character count: 803
# Words in the line: ['Thy', "youth's", 'proud', 'livery', 'so', 'gazed', 'on', 'now,']
# Current word count (last 5 words): {'livery': 1, 'so': 1, 'gazed': 1, 'on': 1, 'now,': 1}
# Processing message...
# Received message...
# Decoded line: Will be a tattered weed of small worth held:
# Cursor position: 850
# Updated total character count: 850
# Words in the line: ['Will', 'be', 'a', 'tattered', 'weed', 'of', 'small', 'worth', 'held:']
# Current word count (last 5 words): {'weed': 1, 'of': 1, 'small': 1, 'worth': 1, 'held:': 1}
# Processing message...
# Received message...
# Decoded line: Then being asked, where all thy beauty lies,
# Cursor position: 897
# Updated total character count: 897
# Words in the line: ['Then', 'being', 'asked,', 'where', 'all', 'thy', 'beauty', 'lies,']
# Current word count (last 5 words): {'then': 1, 'being': 1, 'asked,': 1, 'all': 1, 'beauty': 1}
# Processing message...
# Received message...
# Decoded line: Where all the treasure of thy lusty days;
# Cursor position: 941
# Updated total character count: 941
# Words in the line: ['Where', 'all', 'the', 'treasure', 'of', 'thy', 'lusty', 'days;']
# Current word count (last 5 words): {'all': 2, 'beauty': 1, 'treasure': 1, 'lusty': 1, 'days;': 1}
# Processing message...
# Received message...
# Decoded line: To say within thine own deep sunken eyes,
# Cursor position: 985
# Updated total character count: 985
# Words in the line: ['To', 'say', 'within', 'thine', 'own', 'deep', 'sunken', 'eyes,']
# Current word count (last 5 words): {'treasure': 1, 'lusty': 1, 'days;': 1, 'say': 1, 'sunken': 1}
# Processing message...
# Received message...
# Decoded line: Were an all-eating shame, and thriftless praise.
# Cursor position: 1036
# Updated total character count: 1036
# Words in the line: ['Were', 'an', 'all-eating', 'shame,', 'and', 'thriftless', 'praise.']
# Current word count (last 5 words): {'an': 1, 'all-eating': 1, 'shame,': 1, 'thriftless': 1, 'praise.': 1}
# Processing message...
# Received message...
# Decoded line: How much more praise deserved thy beauty's use,
# Cursor position: 1086
# Updated total character count: 1086
# Words in the line: ['How', 'much', 'more', 'praise', 'deserved', 'thy', "beauty's", 'use,']
# Current word count (last 5 words): {'much': 1, 'more': 1, 'praise': 1, 'deserved': 1, 'use,': 1}
# Processing message...
# Received message...
# Decoded line: If thou couldst answer 'This fair child of mine
# Cursor position: 1136
# Updated total character count: 1136
# Words in the line: ['If', 'thou', 'couldst', 'answer', "'This", 'fair', 'child', 'of', 'mine']
# Current word count (last 5 words): {'answer': 1, "'this": 1, 'fair': 1, 'child': 1, 'mine': 1}
# Processing message...
# Received message...
# Decoded line: Shall sum my count, and make my old excuse'
# Cursor position: 1182
# Updated total character count: 1182
# Words in the line: ['Shall', 'sum', 'my', 'count,', 'and', 'make', 'my', 'old', "excuse'"]
# Current word count (last 5 words): {'my': 2, 'count,': 1, 'make': 1, 'old': 1, "excuse'": 1}
# Processing message...
# Received message...
# Decoded line: Proving his beauty by succession thine.
# Cursor position: 1224
# Updated total character count: 1224
# Words in the line: ['Proving', 'his', 'beauty', 'by', 'succession', 'thine.']
# Current word count (last 5 words): {'old': 1, "excuse'": 1, 'proving': 1, 'succession': 1, 'thine.': 1}
# Processing message...
# Received message...
# Decoded line: This were to be new made when thou art old,
# Cursor position: 1272
# Updated total character count: 1272
# Words in the line: ['This', 'were', 'to', 'be', 'new', 'made', 'when', 'thou', 'art', 'old,']
# Current word count (last 5 words): {'succession': 1, 'thine.': 1, 'new': 1, 'made': 1, 'old,': 1}
# Processing message...
# Received message...
# Decoded line: And see thy blood warm when thou feel'st it cold.
# Cursor position: 1326
# Updated total character count: 1326
# Words in the line: ['And', 'see', 'thy', 'blood', 'warm', 'when', 'thou', "feel'st", 'it', 'cold.']
# Current word count (last 5 words): {'blood': 1, 'warm': 1, "feel'st": 1, 'it': 1, 'cold.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 1327
# Updated total character count: 1327
# Words in the line: []
# Current word count (last 5 words): {'blood': 1, 'warm': 1, "feel'st": 1, 'it': 1, 'cold.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 1328
# Updated total character count: 1328
# Words in the line: []
# Current word count (last 5 words): {'blood': 1, 'warm': 1, "feel'st": 1, 'it': 1, 'cold.': 1}
# Processing message...
# Received message...
# Decoded line: 3
# Cursor position: 1351
# Updated total character count: 1351
# Words in the line: ['3']
# Current word count (last 5 words): {'warm': 1, "feel'st": 1, 'it': 1, 'cold.': 1, '3': 1}
# Processing message...
# Received message...
# Decoded line: Look in thy glass and tell the face thou viewest,
# Cursor position: 1403
# Updated total character count: 1403
# Words in the line: ['Look', 'in', 'thy', 'glass', 'and', 'tell', 'the', 'face', 'thou', 'viewest,']
# Current word count (last 5 words): {'look': 1, 'glass': 1, 'tell': 1, 'face': 1, 'viewest,': 1}
# Processing message...
# Received message...
# Decoded line: Now is the time that face should form another,
# Cursor position: 1452
# Updated total character count: 1452
# Words in the line: ['Now', 'is', 'the', 'time', 'that', 'face', 'should', 'form', 'another,']
# Current word count (last 5 words): {'face': 2, 'viewest,': 1, 'is': 1, 'form': 1, 'another,': 1}
# Processing message...
# Received message...
# Decoded line: Whose fresh repair if now thou not renewest,
# Cursor position: 1499
# Updated total character count: 1499
# Words in the line: ['Whose', 'fresh', 'repair', 'if', 'now', 'thou', 'not', 'renewest,']
# Current word count (last 5 words): {'another,': 1, 'whose': 1, 'repair': 1, 'not': 1, 'renewest,': 1}
# Processing message...
# Received message...
# Decoded line: Thou dost beguile the world, unbless some mother.
# Cursor position: 1551
# Updated total character count: 1551
# Words in the line: ['Thou', 'dost', 'beguile', 'the', 'world,', 'unbless', 'some', 'mother.']
# Current word count (last 5 words): {'dost': 1, 'beguile': 1, 'unbless': 1, 'some': 1, 'mother.': 1}
# Processing message...
# Received message...
# Decoded line: For where is she so fair whose uneared womb
# Cursor position: 1597
# Updated total character count: 1597
# Words in the line: ['For', 'where', 'is', 'she', 'so', 'fair', 'whose', 'uneared', 'womb']
# Current word count (last 5 words): {'mother.': 1, 'for': 1, 'she': 1, 'uneared': 1, 'womb': 1}
# Processing message...
# Received message...
# Decoded line: Disdains the tillage of thy husbandry?
# Cursor position: 1638
# Updated total character count: 1638
# Words in the line: ['Disdains', 'the', 'tillage', 'of', 'thy', 'husbandry?']
# Current word count (last 5 words): {'uneared': 1, 'womb': 1, 'disdains': 1, 'tillage': 1, 'husbandry?': 1}
# Processing message...
# Received message...
# Decoded line: Or who is he so fond will be the tomb,
# Cursor position: 1679
# Updated total character count: 1679
# Words in the line: ['Or', 'who', 'is', 'he', 'so', 'fond', 'will', 'be', 'the', 'tomb,']
# Current word count (last 5 words): {'husbandry?': 1, 'who': 1, 'he': 1, 'fond': 1, 'tomb,': 1}
# Processing message...
# Received message...
# Decoded line: Of his self-love to stop posterity?
# Cursor position: 1717
# Updated total character count: 1717
# Words in the line: ['Of', 'his', 'self-love', 'to', 'stop', 'posterity?']
# Current word count (last 5 words): {'fond': 1, 'tomb,': 1, 'self-love': 1, 'stop': 1, 'posterity?': 1}
# Processing message...
# Received message...
# Decoded line: Thou art thy mother's glass and she in thee
# Cursor position: 1763
# Updated total character count: 1763
# Words in the line: ['Thou', 'art', 'thy', "mother's", 'glass', 'and', 'she', 'in', 'thee']
# Current word count (last 5 words): {'self-love': 1, 'stop': 1, 'posterity?': 1, "mother's": 1, 'thee': 1}
# Processing message...
# Received message...
# Decoded line: Calls back the lovely April of her prime,
# Cursor position: 1807
# Updated total character count: 1807
# Words in the line: ['Calls', 'back', 'the', 'lovely', 'April', 'of', 'her', 'prime,']
# Current word count (last 5 words): {'back': 1, 'lovely': 1, 'april': 1, 'her': 1, 'prime,': 1}
# Processing message...
# Received message...
# Decoded line: So thou through windows of thine age shalt see,
# Cursor position: 1857
# Updated total character count: 1857
# Words in the line: ['So', 'thou', 'through', 'windows', 'of', 'thine', 'age', 'shalt', 'see,']
# Current word count (last 5 words): {'through': 1, 'windows': 1, 'age': 1, 'shalt': 1, 'see,': 1}
# Processing message...
# Received message...
# Decoded line: Despite of wrinkles this thy golden time.
# Cursor position: 1901
# Updated total character count: 1901
# Words in the line: ['Despite', 'of', 'wrinkles', 'this', 'thy', 'golden', 'time.']
# Current word count (last 5 words): {'see,': 1, 'despite': 1, 'wrinkles': 1, 'golden': 1, 'time.': 1}
# Processing message...
# Received message...
# Decoded line: But if thou live remembered not to be,
# Cursor position: 1944
# Updated total character count: 1944
# Words in the line: ['But', 'if', 'thou', 'live', 'remembered', 'not', 'to', 'be,']
# Current word count (last 5 words): {'wrinkles': 1, 'golden': 1, 'time.': 1, 'live': 1, 'remembered': 1}
# Processing message...
# Received message...
# Decoded line: Die single and thine image dies with thee.
# Cursor position: 1991
# Updated total character count: 1991
# Words in the line: ['Die', 'single', 'and', 'thine', 'image', 'dies', 'with', 'thee.']
# Current word count (last 5 words): {'remembered': 1, 'die': 1, 'single': 1, 'image': 1, 'dies': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 1992
# Updated total character count: 1992
# Words in the line: []
# Current word count (last 5 words): {'remembered': 1, 'die': 1, 'single': 1, 'image': 1, 'dies': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 1993
# Updated total character count: 1993
# Words in the line: []
# Current word count (last 5 words): {'remembered': 1, 'die': 1, 'single': 1, 'image': 1, 'dies': 1}
# Processing message...
# Received message...
# Decoded line: 4
# Cursor position: 2016
# Updated total character count: 2016
# Words in the line: ['4']
# Current word count (last 5 words): {'die': 1, 'single': 1, 'image': 1, 'dies': 1, '4': 1}
# Processing message...
# Received message...
# Decoded line: Unthrifty loveliness why dost thou spend,
# Cursor position: 2060
# Updated total character count: 2060
# Words in the line: ['Unthrifty', 'loveliness', 'why', 'dost', 'thou', 'spend,']
# Current word count (last 5 words): {'4': 1, 'unthrifty': 1, 'loveliness': 1, 'why': 1, 'spend,': 1}
# Processing message...
# Received message...
# Decoded line: Upon thy self thy beauty's legacy?
# Cursor position: 2097
# Updated total character count: 2097
# Words in the line: ['Upon', 'thy', 'self', 'thy', "beauty's", 'legacy?']
# Current word count (last 5 words): {'loveliness': 1, 'why': 1, 'spend,': 1, 'upon': 1, 'legacy?': 1}
# Processing message...
# Received message...
# Decoded line: Nature's bequest gives nothing but doth lend,
# Cursor position: 2145
# Updated total character count: 2145
# Words in the line: ["Nature's", 'bequest', 'gives', 'nothing', 'but', 'doth', 'lend,']
# Current word count (last 5 words): {'bequest': 1, 'gives': 1, 'nothing': 1, 'doth': 1, 'lend,': 1}
# Processing message...
# Received message...
# Decoded line: And being frank she lends to those are free:
# Cursor position: 2192
# Updated total character count: 2192
# Words in the line: ['And', 'being', 'frank', 'she', 'lends', 'to', 'those', 'are', 'free:']
# Current word count (last 5 words): {'frank': 1, 'lends': 1, 'those': 1, 'are': 1, 'free:': 1}
# Processing message...
# Received message...
# Decoded line: Then beauteous niggard why dost thou abuse,
# Cursor position: 2238
# Updated total character count: 2238
# Words in the line: ['Then', 'beauteous', 'niggard', 'why', 'dost', 'thou', 'abuse,']
# Current word count (last 5 words): {'are': 1, 'free:': 1, 'beauteous': 1, 'niggard': 1, 'abuse,': 1}
# Processing message...
# Received message...
# Decoded line: The bounteous largess given thee to give?
# Cursor position: 2282
# Updated total character count: 2282
# Words in the line: ['The', 'bounteous', 'largess', 'given', 'thee', 'to', 'give?']
# Current word count (last 5 words): {'abuse,': 1, 'bounteous': 1, 'largess': 1, 'given': 1, 'give?': 1}
# Processing message...
# Received message...
# Decoded line: Profitless usurer why dost thou use
# Cursor position: 2320
# Updated total character count: 2320
# Words in the line: ['Profitless', 'usurer', 'why', 'dost', 'thou', 'use']
# Current word count (last 5 words): {'given': 1, 'give?': 1, 'profitless': 1, 'usurer': 1, 'use': 1}
# Processing message...
# Received message...
# Decoded line: So great a sum of sums yet canst not live?
# Cursor position: 2365
# Updated total character count: 2365
# Words in the line: ['So', 'great', 'a', 'sum', 'of', 'sums', 'yet', 'canst', 'not', 'live?']
# Current word count (last 5 words): {'great': 1, 'sums': 1, 'yet': 1, 'canst': 1, 'live?': 1}
# Processing message...
# Received message...
# Decoded line: For having traffic with thy self alone,
# Cursor position: 2407
# Updated total character count: 2407
# Words in the line: ['For', 'having', 'traffic', 'with', 'thy', 'self', 'alone,']
# Current word count (last 5 words): {'canst': 1, 'live?': 1, 'having': 1, 'traffic': 1, 'alone,': 1}
# Processing message...
# Received message...
# Decoded line: Thou of thy self thy sweet self dost deceive,
# Cursor position: 2455
# Updated total character count: 2455
# Words in the line: ['Thou', 'of', 'thy', 'self', 'thy', 'sweet', 'self', 'dost', 'deceive,']
# Current word count (last 5 words): {'live?': 1, 'having': 1, 'traffic': 1, 'alone,': 1, 'deceive,': 1}
# Processing message...
# Received message...
# Decoded line: Then how when nature calls thee to be gone,
# Cursor position: 2501
# Updated total character count: 2501
# Words in the line: ['Then', 'how', 'when', 'nature', 'calls', 'thee', 'to', 'be', 'gone,']
# Current word count (last 5 words): {'traffic': 1, 'alone,': 1, 'deceive,': 1, 'nature': 1, 'gone,': 1}
# Processing message...
# Received message...
# Decoded line: What acceptable audit canst thou leave?
# Cursor position: 2543
# Updated total character count: 2543
# Words in the line: ['What', 'acceptable', 'audit', 'canst', 'thou', 'leave?']
# Current word count (last 5 words): {'gone,': 1, 'what': 1, 'acceptable': 1, 'audit': 1, 'leave?': 1}
# Processing message...
# Received message...
# Decoded line: Thy unused beauty must be tombed with thee,
# Cursor position: 2591
# Updated total character count: 2591
# Words in the line: ['Thy', 'unused', 'beauty', 'must', 'be', 'tombed', 'with', 'thee,']
# Current word count (last 5 words): {'leave?': 1, 'unused': 1, 'must': 1, 'tombed': 1, 'thee,': 1}
# Processing message...
# Received message...
# Decoded line: Which used lives th' executor to be.
# Cursor position: 2632
# Updated total character count: 2632
# Words in the line: ['Which', 'used', 'lives', "th'", 'executor', 'to', 'be.']
# Current word count (last 5 words): {'used': 1, 'lives': 1, "th'": 1, 'executor': 1, 'be.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 2633
# Updated total character count: 2633
# Words in the line: []
# Current word count (last 5 words): {'used': 1, 'lives': 1, "th'": 1, 'executor': 1, 'be.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 2634
# Updated total character count: 2634
# Words in the line: []
# Current word count (last 5 words): {'used': 1, 'lives': 1, "th'": 1, 'executor': 1, 'be.': 1}
# Processing message...
# Received message...
# Decoded line: 5
# Cursor position: 2657
# Updated total character count: 2657
# Words in the line: ['5']
# Current word count (last 5 words): {'lives': 1, "th'": 1, 'executor': 1, 'be.': 1, '5': 1}
# Processing message...
# Received message...
# Decoded line: Those hours that with gentle work did frame
# Cursor position: 2703
# Updated total character count: 2703
# Words in the line: ['Those', 'hours', 'that', 'with', 'gentle', 'work', 'did', 'frame']
# Current word count (last 5 words): {'hours': 1, 'gentle': 1, 'work': 1, 'did': 1, 'frame': 1}
# Processing message...
# Received message...
# Decoded line: The lovely gaze where every eye doth dwell
# Cursor position: 2748
# Updated total character count: 2748
# Words in the line: ['The', 'lovely', 'gaze', 'where', 'every', 'eye', 'doth', 'dwell']
# Current word count (last 5 words): {'frame': 1, 'gaze': 1, 'every': 1, 'eye': 1, 'dwell': 1}
# Processing message...
# Received message...
# Decoded line: Will play the tyrants to the very same,
# Cursor position: 2790
# Updated total character count: 2790
# Words in the line: ['Will', 'play', 'the', 'tyrants', 'to', 'the', 'very', 'same,']
# Current word count (last 5 words): {'dwell': 1, 'play': 1, 'tyrants': 1, 'very': 1, 'same,': 1}
# Processing message...
# Received message...
# Decoded line: And that unfair which fairly doth excel:
# Cursor position: 2833
# Updated total character count: 2833
# Words in the line: ['And', 'that', 'unfair', 'which', 'fairly', 'doth', 'excel:']
# Current word count (last 5 words): {'very': 1, 'same,': 1, 'unfair': 1, 'fairly': 1, 'excel:': 1}
# Processing message...
# Received message...
# Decoded line: For never-resting time leads summer on
# Cursor position: 2874
# Updated total character count: 2874
# Words in the line: ['For', 'never-resting', 'time', 'leads', 'summer', 'on']
# Current word count (last 5 words): {'fairly': 1, 'excel:': 1, 'never-resting': 1, 'leads': 1, 'summer': 1}
# Processing message...
# Received message...
# Decoded line: To hideous winter and confounds him there,
# Cursor position: 2919
# Updated total character count: 2919
# Words in the line: ['To', 'hideous', 'winter', 'and', 'confounds', 'him', 'there,']
# Current word count (last 5 words): {'hideous': 1, 'winter': 1, 'confounds': 1, 'him': 1, 'there,': 1}
# Processing message...
# Received message...
# Decoded line: Sap checked with frost and lusty leaves quite gone,
# Cursor position: 2973
# Updated total character count: 2973
# Words in the line: ['Sap', 'checked', 'with', 'frost', 'and', 'lusty', 'leaves', 'quite', 'gone,']
# Current word count (last 5 words): {'sap': 1, 'checked': 1, 'frost': 1, 'leaves': 1, 'quite': 1}
# Processing message...
# Received message...
# Decoded line: Beauty o'er-snowed and bareness every where:
# Cursor position: 3020
# Updated total character count: 3020
# Words in the line: ['Beauty', "o'er-snowed", 'and', 'bareness', 'every', 'where:']
# Current word count (last 5 words): {'leaves': 1, 'quite': 1, "o'er-snowed": 1, 'bareness': 1, 'where:': 1}
# Processing message...
# Received message...
# Decoded line: Then were not summer's distillation left
# Cursor position: 3063
# Updated total character count: 3063
# Words in the line: ['Then', 'were', 'not', "summer's", 'distillation', 'left']
# Current word count (last 5 words): {'bareness': 1, 'where:': 1, "summer's": 1, 'distillation': 1, 'left': 1}
# Processing message...
# Received message...
# Decoded line: A liquid prisoner pent in walls of glass,
# Cursor position: 3107
# Updated total character count: 3107
# Words in the line: ['A', 'liquid', 'prisoner', 'pent', 'in', 'walls', 'of', 'glass,']
# Current word count (last 5 words): {'liquid': 1, 'prisoner': 1, 'pent': 1, 'walls': 1, 'glass,': 1}
# Processing message...
# Received message...
# Decoded line: Beauty's effect with beauty were bereft,
# Cursor position: 3150
# Updated total character count: 3150
# Words in the line: ["Beauty's", 'effect', 'with', 'beauty', 'were', 'bereft,']
# Current word count (last 5 words): {'pent': 1, 'walls': 1, 'glass,': 1, 'effect': 1, 'bereft,': 1}
# Processing message...
# Received message...
# Decoded line: Nor it nor no remembrance what it was.
# Cursor position: 3191
# Updated total character count: 3191
# Words in the line: ['Nor', 'it', 'nor', 'no', 'remembrance', 'what', 'it', 'was.']
# Current word count (last 5 words): {'bereft,': 1, 'nor': 2, 'no': 1, 'remembrance': 1, 'was.': 1}
# Processing message...
# Received message...
# Decoded line: But flowers distilled though they with winter meet,
# Cursor position: 3247
# Updated total character count: 3247
# Words in the line: ['But', 'flowers', 'distilled', 'though', 'they', 'with', 'winter', 'meet,']
# Current word count (last 5 words): {'flowers': 1, 'distilled': 1, 'though': 1, 'they': 1, 'meet,': 1}
# Processing message...
# Received message...
# Decoded line: Leese but their show, their substance still lives sweet.
# Cursor position: 3308
# Updated total character count: 3308
# Words in the line: ['Leese', 'but', 'their', 'show,', 'their', 'substance', 'still', 'lives', 'sweet.']
# Current word count (last 5 words): {'their': 2, 'show,': 1, 'substance': 1, 'still': 1, 'sweet.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 3309
# Updated total character count: 3309
# Words in the line: []
# Current word count (last 5 words): {'their': 2, 'show,': 1, 'substance': 1, 'still': 1, 'sweet.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 3310
# Updated total character count: 3310
# Words in the line: []
# Current word count (last 5 words): {'their': 2, 'show,': 1, 'substance': 1, 'still': 1, 'sweet.': 1}
# Processing message...
# Received message...
# Decoded line: 6
# Cursor position: 3333
# Updated total character count: 3333
# Words in the line: ['6']
# Current word count (last 5 words): {'show,': 1, 'substance': 1, 'still': 1, 'sweet.': 1, '6': 1}
# Processing message...
# Received message...
# Decoded line: Then let not winter's ragged hand deface,
# Cursor position: 3377
# Updated total character count: 3377
# Words in the line: ['Then', 'let', 'not', "winter's", 'ragged', 'hand', 'deface,']
# Current word count (last 5 words): {'let': 1, "winter's": 1, 'ragged': 1, 'hand': 1, 'deface,': 1}
# Processing message...
# Received message...
# Decoded line: In thee thy summer ere thou be distilled:
# Cursor position: 3421
# Updated total character count: 3421
# Words in the line: ['In', 'thee', 'thy', 'summer', 'ere', 'thou', 'be', 'distilled:']
# Current word count (last 5 words): {'ragged': 1, 'hand': 1, 'deface,': 1, 'ere': 1, 'distilled:': 1}
# Processing message...
# Received message...
# Decoded line: Make sweet some vial; treasure thou some place,
# Cursor position: 3471
# Updated total character count: 3471
# Words in the line: ['Make', 'sweet', 'some', 'vial;', 'treasure', 'thou', 'some', 'place,']
# Current word count (last 5 words): {'deface,': 1, 'ere': 1, 'distilled:': 1, 'vial;': 1, 'place,': 1}
# Processing message...
# Received message...
# Decoded line: With beauty's treasure ere it be self-killed:
# Cursor position: 3519
# Updated total character count: 3519
# Words in the line: ['With', "beauty's", 'treasure', 'ere', 'it', 'be', 'self-killed:']
# Current word count (last 5 words): {'ere': 2, 'distilled:': 1, 'vial;': 1, 'place,': 1, 'self-killed:': 1}
# Processing message...
# Received message...
# Decoded line: That use is not forbidden usury,
# Cursor position: 3554
# Updated total character count: 3554
# Words in the line: ['That', 'use', 'is', 'not', 'forbidden', 'usury,']
# Current word count (last 5 words): {'vial;': 1, 'place,': 1, 'self-killed:': 1, 'forbidden': 1, 'usury,': 1}
# Processing message...
# Received message...
# Decoded line: Which happies those that pay the willing loan;
# Cursor position: 3603
# Updated total character count: 3603
# Words in the line: ['Which', 'happies', 'those', 'that', 'pay', 'the', 'willing', 'loan;']
# Current word count (last 5 words): {'usury,': 1, 'happies': 1, 'pay': 1, 'willing': 1, 'loan;': 1}
# Processing message...
# Received message...
# Decoded line: That's for thy self to breed another thee,
# Cursor position: 3648
# Updated total character count: 3648
# Words in the line: ["That's", 'for', 'thy', 'self', 'to', 'breed', 'another', 'thee,']
# Current word count (last 5 words): {'willing': 1, 'loan;': 1, "that's": 1, 'breed': 1, 'another': 1}
# Processing message...
# Received message...
# Decoded line: Or ten times happier be it ten for one,
# Cursor position: 3690
# Updated total character count: 3690
# Words in the line: ['Or', 'ten', 'times', 'happier', 'be', 'it', 'ten', 'for', 'one,']
# Current word count (last 5 words): {'another': 1, 'ten': 2, 'times': 1, 'happier': 1, 'one,': 1}
# Processing message...
# Received message...
# Decoded line: Ten times thy self were happier than thou art,
# Cursor position: 3739
# Updated total character count: 3739
# Words in the line: ['Ten', 'times', 'thy', 'self', 'were', 'happier', 'than', 'thou', 'art,']
# Current word count (last 5 words): {'times': 2, 'happier': 2, 'one,': 1, 'than': 1, 'art,': 1}
# Processing message...
# Received message...
# Decoded line: If ten of thine ten times refigured thee:
# Cursor position: 3783
# Updated total character count: 3783
# Words in the line: ['If', 'ten', 'of', 'thine', 'ten', 'times', 'refigured', 'thee:']
# Current word count (last 5 words): {'one,': 1, 'than': 1, 'art,': 1, 'refigured': 1, 'thee:': 1}
# Processing message...
# Received message...
# Decoded line: Then what could death do if thou shouldst depart,
# Cursor position: 3835
# Updated total character count: 3835
# Words in the line: ['Then', 'what', 'could', 'death', 'do', 'if', 'thou', 'shouldst', 'depart,']
# Current word count (last 5 words): {'could': 1, 'death': 1, 'do': 1, 'shouldst': 1, 'depart,': 1}
# Processing message...
# Received message...
# Decoded line: Leaving thee living in posterity?
# Cursor position: 3871
# Updated total character count: 3871
# Words in the line: ['Leaving', 'thee', 'living', 'in', 'posterity?']
# Current word count (last 5 words): {'do': 1, 'shouldst': 1, 'depart,': 1, 'leaving': 1, 'living': 1}
# Processing message...
# Received message...
# Decoded line: Be not self-willed for thou art much too fair,
# Cursor position: 3922
# Updated total character count: 3922
# Words in the line: ['Be', 'not', 'self-willed', 'for', 'thou', 'art', 'much', 'too', 'fair,']
# Current word count (last 5 words): {'depart,': 1, 'leaving': 1, 'living': 1, 'self-willed': 1, 'fair,': 1}
# Processing message...
# Received message...
# Decoded line: To be death's conquest and make worms thine heir.
# Cursor position: 3976
# Updated total character count: 3976
# Words in the line: ['To', 'be', "death's", 'conquest', 'and', 'make', 'worms', 'thine', 'heir.']
# Current word count (last 5 words): {'fair,': 1, "death's": 1, 'conquest': 1, 'worms': 1, 'heir.': 1}
#
# Top 5 most frequent words:
# thy: 25
# thou: 21
# the: 18
# to: 16
# and: 16
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 3977
# Updated total character count: 3977
# Words in the line: []
# Current word count (last 5 words): {'fair,': 1, "death's": 1, 'conquest': 1, 'worms': 1, 'heir.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 3978
# Updated total character count: 3978
# Words in the line: []
# Current word count (last 5 words): {'fair,': 1, "death's": 1, 'conquest': 1, 'worms': 1, 'heir.': 1}
# Processing message...
# Received message...
# Decoded line: 7
# Cursor position: 4001
# Updated total character count: 4001
# Words in the line: ['7']
# Current word count (last 5 words): {"death's": 1, 'conquest': 1, 'worms': 1, 'heir.': 1, '7': 1}
# Processing message...
# Received message...
# Decoded line: Lo in the orient when the gracious light
# Cursor position: 4044
# Updated total character count: 4044
# Words in the line: ['Lo', 'in', 'the', 'orient', 'when', 'the', 'gracious', 'light']
# Current word count (last 5 words): {'7': 1, 'lo': 1, 'orient': 1, 'gracious': 1, 'light': 1}
# Processing message...
# Received message...
# Decoded line: Lifts up his burning head, each under eye
# Cursor position: 4088
# Updated total character count: 4088
# Words in the line: ['Lifts', 'up', 'his', 'burning', 'head,', 'each', 'under', 'eye']
# Current word count (last 5 words): {'up': 1, 'burning': 1, 'head,': 1, 'each': 1, 'under': 1}
# Processing message...
# Received message...
# Decoded line: Doth homage to his new-appearing sight,
# Cursor position: 4130
# Updated total character count: 4130
# Words in the line: ['Doth', 'homage', 'to', 'his', 'new-appearing', 'sight,']
# Current word count (last 5 words): {'each': 1, 'under': 1, 'homage': 1, 'new-appearing': 1, 'sight,': 1}
# Processing message...
# Received message...
# Decoded line: Serving with looks his sacred majesty,
# Cursor position: 4171
# Updated total character count: 4171
# Words in the line: ['Serving', 'with', 'looks', 'his', 'sacred', 'majesty,']
# Current word count (last 5 words): {'sight,': 1, 'serving': 1, 'looks': 1, 'sacred': 1, 'majesty,': 1}
# Processing message...
# Received message...
# Decoded line: And having climbed the steep-up heavenly hill,
# Cursor position: 4220
# Updated total character count: 4220
# Words in the line: ['And', 'having', 'climbed', 'the', 'steep-up', 'heavenly', 'hill,']
# Current word count (last 5 words): {'majesty,': 1, 'climbed': 1, 'steep-up': 1, 'heavenly': 1, 'hill,': 1}
# Processing message...
# Received message...
# Decoded line: Resembling strong youth in his middle age,
# Cursor position: 4265
# Updated total character count: 4265
# Words in the line: ['Resembling', 'strong', 'youth', 'in', 'his', 'middle', 'age,']
# Current word count (last 5 words): {'resembling': 1, 'strong': 1, 'youth': 1, 'middle': 1, 'age,': 1}
# Processing message...
# Received message...
# Decoded line: Yet mortal looks adore his beauty still,
# Cursor position: 4308
# Updated total character count: 4308
# Words in the line: ['Yet', 'mortal', 'looks', 'adore', 'his', 'beauty', 'still,']
# Current word count (last 5 words): {'middle': 1, 'age,': 1, 'mortal': 1, 'adore': 1, 'still,': 1}
#
# Top 5 most frequent words:
# thy: 25
# the: 21
# thou: 21
# to: 17
# and: 17
# Processing message...
# Received message...
# Decoded line: Attending on his golden pilgrimage:
# Cursor position: 4346
# Updated total character count: 4346
# Words in the line: ['Attending', 'on', 'his', 'golden', 'pilgrimage:']
# Current word count (last 5 words): {'mortal': 1, 'adore': 1, 'still,': 1, 'attending': 1, 'pilgrimage:': 1}
# Processing message...
# Received message...
# Decoded line: But when from highmost pitch with weary car,
# Cursor position: 4393
# Updated total character count: 4393
# Words in the line: ['But', 'when', 'from', 'highmost', 'pitch', 'with', 'weary', 'car,']
# Current word count (last 5 words): {'pilgrimage:': 1, 'highmost': 1, 'pitch': 1, 'weary': 1, 'car,': 1}
# Processing message...
# Received message...
# Decoded line: Like feeble age he reeleth from the day,
# Cursor position: 4436
# Updated total character count: 4436
# Words in the line: ['Like', 'feeble', 'age', 'he', 'reeleth', 'from', 'the', 'day,']
# Current word count (last 5 words): {'car,': 1, 'like': 1, 'feeble': 1, 'reeleth': 1, 'day,': 1}
# Processing message...
# Received message...
# Decoded line: The eyes (fore duteous) now converted are
# Cursor position: 4480
# Updated total character count: 4480
# Words in the line: ['The', 'eyes', '(fore', 'duteous)', 'now', 'converted', 'are']
# Current word count (last 5 words): {'day,': 1, 'eyes': 1, '(fore': 1, 'duteous)': 1, 'converted': 1}
# Processing message...
# Received message...
# Decoded line: From his low tract and look another way:
# Cursor position: 4523
# Updated total character count: 4523
# Words in the line: ['From', 'his', 'low', 'tract', 'and', 'look', 'another', 'way:']
# Current word count (last 5 words): {'duteous)': 1, 'converted': 1, 'low': 1, 'tract': 1, 'way:': 1}
# Processing message...
# Received message...
# Decoded line: So thou, thy self out-going in thy noon:
# Cursor position: 4568
# Updated total character count: 4568
# Words in the line: ['So', 'thou,', 'thy', 'self', 'out-going', 'in', 'thy', 'noon:']
# Current word count (last 5 words): {'tract': 1, 'way:': 1, 'thou,': 1, 'out-going': 1, 'noon:': 1}
# Processing message...
# Received message...
# Decoded line: Unlooked on diest unless thou get a son.
# Cursor position: 4613
# Updated total character count: 4613
# Words in the line: ['Unlooked', 'on', 'diest', 'unless', 'thou', 'get', 'a', 'son.']
# Current word count (last 5 words): {'unlooked': 1, 'diest': 1, 'unless': 1, 'get': 1, 'son.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 4614
# Updated total character count: 4614
# Words in the line: []
# Current word count (last 5 words): {'unlooked': 1, 'diest': 1, 'unless': 1, 'get': 1, 'son.': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 4615
# Updated total character count: 4615
# Words in the line: []
# Current word count (last 5 words): {'unlooked': 1, 'diest': 1, 'unless': 1, 'get': 1, 'son.': 1}
# Processing message...
# Received message...
# Decoded line: 8
# Cursor position: 4638
# Updated total character count: 4638
# Words in the line: ['8']
# Current word count (last 5 words): {'diest': 1, 'unless': 1, 'get': 1, 'son.': 1, '8': 1}
#
# Top 5 most frequent words:
# thy: 27
# the: 23
# thou: 22
# and: 18
# to: 17
# Processing message...
# Received message...
# Decoded line: Music to hear, why hear'st thou music sadly?
# Cursor position: 4685
# Updated total character count: 4685
# Words in the line: ['Music', 'to', 'hear,', 'why', "hear'st", 'thou', 'music', 'sadly?']
# Current word count (last 5 words): {'8': 1, 'music': 2, 'hear,': 1, "hear'st": 1, 'sadly?': 1}
# Processing message...
# Received message...
# Decoded line: Sweets with sweets war not, joy delights in joy:
# Cursor position: 4736
# Updated total character count: 4736
# Words in the line: ['Sweets', 'with', 'sweets', 'war', 'not,', 'joy', 'delights', 'in', 'joy:']
# Current word count (last 5 words): {'war': 1, 'not,': 1, 'joy': 1, 'delights': 1, 'joy:': 1}
# Processing message...
# Received message...
# Decoded line: Why lov'st thou that which thou receiv'st not gladly,
# Cursor position: 4792
# Updated total character count: 4792
# Words in the line: ['Why', "lov'st", 'thou', 'that', 'which', 'thou', "receiv'st", 'not', 'gladly,']
# Current word count (last 5 words): {'delights': 1, 'joy:': 1, "lov'st": 1, "receiv'st": 1, 'gladly,': 1}
# Processing message...
# Received message...
# Decoded line: Or else receiv'st with pleasure thine annoy?
# Cursor position: 4839
# Updated total character count: 4839
# Words in the line: ['Or', 'else', "receiv'st", 'with', 'pleasure', 'thine', 'annoy?']
# Current word count (last 5 words): {"lov'st": 1, "receiv'st": 2, 'gladly,': 1, 'pleasure': 1, 'annoy?': 1}
# Processing message...
# Received message...
# Decoded line: If the true concord of well-tuned sounds,
# Cursor position: 4883
# Updated total character count: 4883
# Words in the line: ['If', 'the', 'true', 'concord', 'of', 'well-tuned', 'sounds,']
# Current word count (last 5 words): {'annoy?': 1, 'true': 1, 'concord': 1, 'well-tuned': 1, 'sounds,': 1}
# Processing message...
# Received message...
# Decoded line: By unions married do offend thine ear,
# Cursor position: 4924
# Updated total character count: 4924
# Words in the line: ['By', 'unions', 'married', 'do', 'offend', 'thine', 'ear,']
# Current word count (last 5 words): {'sounds,': 1, 'unions': 1, 'married': 1, 'offend': 1, 'ear,': 1}
# Processing message...
# Received message...
# Decoded line: They do but sweetly chide thee, who confounds
# Cursor position: 4972
# Updated total character count: 4972
# Words in the line: ['They', 'do', 'but', 'sweetly', 'chide', 'thee,', 'who', 'confounds']
# Current word count (last 5 words): {'married': 1, 'offend': 1, 'ear,': 1, 'sweetly': 1, 'chide': 1}
# Processing message...
# Received message...
# Decoded line: In singleness the parts that thou shouldst bear:
# Cursor position: 5023
# Updated total character count: 5023
# Words in the line: ['In', 'singleness', 'the', 'parts', 'that', 'thou', 'shouldst', 'bear:']
# Current word count (last 5 words): {'sweetly': 1, 'chide': 1, 'singleness': 1, 'parts': 1, 'bear:': 1}
# Processing message...
# Received message...
# Decoded line: Mark how one string sweet husband to another,
# Cursor position: 5071
# Updated total character count: 5071
# Words in the line: ['Mark', 'how', 'one', 'string', 'sweet', 'husband', 'to', 'another,']
# Current word count (last 5 words): {'bear:': 1, 'mark': 1, 'one': 1, 'string': 1, 'husband': 1}
# Processing message...
# Received message...
# Decoded line: Strikes each in each by mutual ordering;
# Cursor position: 5114
# Updated total character count: 5114
# Words in the line: ['Strikes', 'each', 'in', 'each', 'by', 'mutual', 'ordering;']
# Current word count (last 5 words): {'string': 1, 'husband': 1, 'strikes': 1, 'mutual': 1, 'ordering;': 1}
#
# Top 5 most frequent words:
# thy: 27
# thou: 26
# the: 25
# to: 19
# and: 18
# Processing message...
# Received message...
# Decoded line: Resembling sire, and child, and happy mother,
# Cursor position: 5162
# Updated total character count: 5162
# Words in the line: ['Resembling', 'sire,', 'and', 'child,', 'and', 'happy', 'mother,']
# Current word count (last 5 words): {'ordering;': 1, 'sire,': 1, 'child,': 1, 'happy': 1, 'mother,': 1}
# Processing message...
# Received message...
# Decoded line: Who all in one, one pleasing note do sing:
# Cursor position: 5207
# Updated total character count: 5207
# Words in the line: ['Who', 'all', 'in', 'one,', 'one', 'pleasing', 'note', 'do', 'sing:']
# Current word count (last 5 words): {'happy': 1, 'mother,': 1, 'pleasing': 1, 'note': 1, 'sing:': 1}
# Processing message...
# Received message...
# Decoded line: Whose speechless song being many, seeming one,
# Cursor position: 5258
# Updated total character count: 5258
# Words in the line: ['Whose', 'speechless', 'song', 'being', 'many,', 'seeming', 'one,']
# Current word count (last 5 words): {'sing:': 1, 'speechless': 1, 'song': 1, 'many,': 1, 'seeming': 1}
# Processing message...
# Received message...
# Decoded line: Sings this to thee, 'Thou single wilt prove none'.
# Cursor position: 5313
# Updated total character count: 5313
# Words in the line: ['Sings', 'this', 'to', 'thee,', "'Thou", 'single', 'wilt', 'prove', "none'."]
# Current word count (last 5 words): {'sings': 1, "'thou": 1, 'wilt': 1, 'prove': 1, "none'.": 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 5314
# Updated total character count: 5314
# Words in the line: []
# Current word count (last 5 words): {'sings': 1, "'thou": 1, 'wilt': 1, 'prove': 1, "none'.": 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 5315
# Updated total character count: 5315
# Words in the line: []
# Current word count (last 5 words): {'sings': 1, "'thou": 1, 'wilt': 1, 'prove': 1, "none'.": 1}
# Processing message...
# Received message...
# Decoded line: 9
# Cursor position: 5338
# Updated total character count: 5338
# Words in the line: ['9']
# Current word count (last 5 words): {"'thou": 1, 'wilt': 1, 'prove': 1, "none'.": 1, '9': 1}
# Processing message...
# Received message...
# Decoded line: Is it for fear to wet a widow's eye,
# Cursor position: 5377
# Updated total character count: 5377
# Words in the line: ['Is', 'it', 'for', 'fear', 'to', 'wet', 'a', "widow's", 'eye,']
# Current word count (last 5 words): {'9': 1, 'fear': 1, 'wet': 1, "widow's": 1, 'eye,': 1}
# Processing message...
# Received message...
# Decoded line: That thou consum'st thy self in single life?
# Cursor position: 5424
# Updated total character count: 5424
# Words in the line: ['That', 'thou', "consum'st", 'thy', 'self', 'in', 'single', 'life?']
# Current word count (last 5 words): {'wet': 1, "widow's": 1, 'eye,': 1, "consum'st": 1, 'life?': 1}
# Processing message...
# Received message...
# Decoded line: Ah, if thou issueless shalt hap to die,
# Cursor position: 5466
# Updated total character count: 5466
# Words in the line: ['Ah,', 'if', 'thou', 'issueless', 'shalt', 'hap', 'to', 'die,']
# Current word count (last 5 words): {"consum'st": 1, 'life?': 1, 'ah,': 1, 'issueless': 1, 'hap': 1}
#
# Top 5 most frequent words:
# thou: 28
# thy: 28
# the: 25
# to: 22
# and: 20
# Processing message...
# Received message...
# Decoded line: The world will wail thee like a makeless wife,
# Cursor position: 5515
# Updated total character count: 5515
# Words in the line: ['The', 'world', 'will', 'wail', 'thee', 'like', 'a', 'makeless', 'wife,']
# Current word count (last 5 words): {'hap': 1, 'world': 1, 'wail': 1, 'makeless': 1, 'wife,': 1}
# Processing message...
# Received message...
# Decoded line: The world will be thy widow and still weep,
# Cursor position: 5561
# Updated total character count: 5561
# Words in the line: ['The', 'world', 'will', 'be', 'thy', 'widow', 'and', 'still', 'weep,']
# Current word count (last 5 words): {'wail': 1, 'makeless': 1, 'wife,': 1, 'widow': 1, 'weep,': 1}
# Processing message...
# Received message...
# Decoded line: That thou no form of thee hast left behind,
# Cursor position: 5607
# Updated total character count: 5607
# Words in the line: ['That', 'thou', 'no', 'form', 'of', 'thee', 'hast', 'left', 'behind,']
# Current word count (last 5 words): {'wife,': 1, 'widow': 1, 'weep,': 1, 'hast': 1, 'behind,': 1}
# Processing message...
# Received message...
# Decoded line: When every private widow well may keep,
# Cursor position: 5649
# Updated total character count: 5649
# Words in the line: ['When', 'every', 'private', 'widow', 'well', 'may', 'keep,']
# Current word count (last 5 words): {'behind,': 1, 'private': 1, 'well': 1, 'may': 1, 'keep,': 1}
# Processing message...
# Received message...
# Decoded line: By children's eyes, her husband's shape in mind:
# Cursor position: 5700
# Updated total character count: 5700
# Words in the line: ['By', "children's", 'eyes,', 'her', "husband's", 'shape', 'in', 'mind:']
# Current word count (last 5 words): {'keep,': 1, "children's": 1, "husband's": 1, 'shape': 1, 'mind:': 1}
# Processing message...
# Received message...
# Decoded line: Look what an unthrift in the world doth spend
# Cursor position: 5748
# Updated total character count: 5748
# Words in the line: ['Look', 'what', 'an', 'unthrift', 'in', 'the', 'world', 'doth', 'spend']
# Current word count (last 5 words): {"husband's": 1, 'shape': 1, 'mind:': 1, 'unthrift': 1, 'spend': 1}
# Processing message...
# Received message...
# Decoded line: Shifts but his place, for still the world enjoys it;
# Cursor position: 5803
# Updated total character count: 5803
# Words in the line: ['Shifts', 'but', 'his', 'place,', 'for', 'still', 'the', 'world', 'enjoys', 'it;']
# ...
# Updated total character count: 78144
# Words in the line: ['Since', 'my', 'appeal', 'says', 'I', 'did', 'strive', 'to', 'prove']
# Current word count (last 5 words): {'shoot': 1, 'wakened': 1, 'hate:': 1, 'appeal': 1, 'strive': 1}
#
# Top 5 most frequent words:
# and: 377
# the: 357
# of: 299
# to: 294
# my: 273
# Processing message...
# Received message...
# Decoded line: The constancy and virtue of your love.
# Cursor position: 78187
# Updated total character count: 78187
# Words in the line: ['The', 'constancy', 'and', 'virtue', 'of', 'your', 'love.']
# Current word count (last 5 words): {'shoot': 1, 'wakened': 1, 'hate:': 1, 'appeal': 1, 'strive': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 78188
# Updated total character count: 78188
# Words in the line: []
# Current word count (last 5 words): {'shoot': 1, 'wakened': 1, 'hate:': 1, 'appeal': 1, 'strive': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 78189
# Updated total character count: 78189
# Words in the line: []
# Current word count (last 5 words): {'shoot': 1, 'wakened': 1, 'hate:': 1, 'appeal': 1, 'strive': 1}
# Processing message...
# Received message...
# Decoded line: 118
# Cursor position: 78214
# Updated total character count: 78214
# Words in the line: ['118']
# Current word count (last 5 words): {'wakened': 1, 'hate:': 1, 'appeal': 1, 'strive': 1, '118': 1}
# Processing message...
# Received message...
# Decoded line: Like as to make our appetite more keen
# Cursor position: 78255
# Updated total character count: 78255
# Words in the line: ['Like', 'as', 'to', 'make', 'our', 'appetite', 'more', 'keen']
# Current word count (last 5 words): {'wakened': 1, 'hate:': 1, 'appeal': 1, 'strive': 1, '118': 1}
# Processing message...
# Received message...
# Decoded line: With eager compounds we our palate urge,
# Cursor position: 78298
# Updated total character count: 78298
# Words in the line: ['With', 'eager', 'compounds', 'we', 'our', 'palate', 'urge,']
# Current word count (last 5 words): {'appeal': 1, 'strive': 1, '118': 1, 'eager': 1, 'urge,': 1}
# Processing message...
# Received message...
# Decoded line: As to prevent our maladies unseen,
# Cursor position: 78335
# Updated total character count: 78335
# Words in the line: ['As', 'to', 'prevent', 'our', 'maladies', 'unseen,']
# Current word count (last 5 words): {'eager': 1, 'urge,': 1, 'prevent': 1, 'maladies': 1, 'unseen,': 1}
# Processing message...
# Received message...
# Decoded line: We sicken to shun sickness when we purge.
# Cursor position: 78379
# Updated total character count: 78379
# Words in the line: ['We', 'sicken', 'to', 'shun', 'sickness', 'when', 'we', 'purge.']
# Current word count (last 5 words): {'unseen,': 1, 'sicken': 1, 'shun': 1, 'sickness': 1, 'purge.': 1}
# Processing message...
# Received message...
# Decoded line: Even so being full of your ne'er-cloying sweetness,
# Cursor position: 78433
# Updated total character count: 78433
# Words in the line: ['Even', 'so', 'being', 'full', 'of', 'your', "ne'er-cloying", 'sweetness,']
# Current word count (last 5 words): {'shun': 1, 'sickness': 1, 'purge.': 1, "ne'er-cloying": 1, 'sweetness,': 1}
# Processing message...
# Received message...
# Decoded line: To bitter sauces did I frame my feeding;
# Cursor position: 78476
# Updated total character count: 78476
# Words in the line: ['To', 'bitter', 'sauces', 'did', 'I', 'frame', 'my', 'feeding;']
# Current word count (last 5 words): {'purge.': 1, "ne'er-cloying": 1, 'sweetness,': 1, 'sauces': 1, 'feeding;': 1}
#
# Top 5 most frequent words:
# and: 378
# the: 358
# of: 301
# to: 298
# my: 274
# Processing message...
# Received message...
# Decoded line: And sick of welfare found a kind of meetness,
# Cursor position: 78524
# Updated total character count: 78524
# Words in the line: ['And', 'sick', 'of', 'welfare', 'found', 'a', 'kind', 'of', 'meetness,']
# Current word count (last 5 words): {'sweetness,': 1, 'sauces': 1, 'feeding;': 1, 'welfare': 1, 'meetness,': 1}
# Processing message...
# Received message...
# Decoded line: To be diseased ere that there was true needing.
# Cursor position: 78574
# Updated total character count: 78574
# Words in the line: ['To', 'be', 'diseased', 'ere', 'that', 'there', 'was', 'true', 'needing.']
# Current word count (last 5 words): {'feeding;': 1, 'welfare': 1, 'meetness,': 1, 'diseased': 1, 'needing.': 1}
# Processing message...
# Received message...
# Decoded line: Thus policy in love t' anticipate
# Cursor position: 78610
# Updated total character count: 78610
# Words in the line: ['Thus', 'policy', 'in', 'love', "t'", 'anticipate']
# Current word count (last 5 words): {'diseased': 1, 'needing.': 1, 'policy': 1, "t'": 1, 'anticipate': 1}
# Processing message...
# Received message...
# Decoded line: The ills that were not, grew to faults assured,
# Cursor position: 78660
# Updated total character count: 78660
# Words in the line: ['The', 'ills', 'that', 'were', 'not,', 'grew', 'to', 'faults', 'assured,']
# Current word count (last 5 words): {'policy': 1, "t'": 1, 'anticipate': 1, 'ills': 1, 'grew': 1}
# Processing message...
# Received message...
# Decoded line: And brought to medicine a healthful state
# Cursor position: 78704
# Updated total character count: 78704
# Words in the line: ['And', 'brought', 'to', 'medicine', 'a', 'healthful', 'state']
# Current word count (last 5 words): {'anticipate': 1, 'ills': 1, 'grew': 1, 'medicine': 1, 'healthful': 1}
# Processing message...
# Received message...
# Decoded line: Which rank of goodness would by ill be cured.
# Cursor position: 78752
# Updated total character count: 78752
# Words in the line: ['Which', 'rank', 'of', 'goodness', 'would', 'by', 'ill', 'be', 'cured.']
# Current word count (last 5 words): {'grew': 1, 'medicine': 1, 'healthful': 1, 'goodness': 1, 'cured.': 1}
# Processing message...
# Received message...
# Decoded line: But thence I learn and find the lesson true,
# Cursor position: 78801
# Updated total character count: 78801
# Words in the line: ['But', 'thence', 'I', 'learn', 'and', 'find', 'the', 'lesson', 'true,']
# Current word count (last 5 words): {'medicine': 1, 'healthful': 1, 'goodness': 1, 'cured.': 1, 'lesson': 1}
# Processing message...
# Received message...
# Decoded line: Drugs poison him that so feil sick of you.
# Cursor position: 78848
# Updated total character count: 78848
# Words in the line: ['Drugs', 'poison', 'him', 'that', 'so', 'feil', 'sick', 'of', 'you.']
# Current word count (last 5 words): {'cured.': 1, 'lesson': 1, 'drugs': 1, 'poison': 1, 'feil': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 78849
# Updated total character count: 78849
# Words in the line: []
# Current word count (last 5 words): {'cured.': 1, 'lesson': 1, 'drugs': 1, 'poison': 1, 'feil': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 78850
# Updated total character count: 78850
# Words in the line: []
# Current word count (last 5 words): {'cured.': 1, 'lesson': 1, 'drugs': 1, 'poison': 1, 'feil': 1}
#
# Top 5 most frequent words:
# and: 381
# the: 360
# of: 305
# to: 301
# my: 274
# Processing message...
# Received message...
# Decoded line: 119
# Cursor position: 78875
# Updated total character count: 78875
# Words in the line: ['119']
# Current word count (last 5 words): {'lesson': 1, 'drugs': 1, 'poison': 1, 'feil': 1, '119': 1}
# Processing message...
# Received message...
# Decoded line: What potions have I drunk of Siren tears
# Cursor position: 78918
# Updated total character count: 78918
# Words in the line: ['What', 'potions', 'have', 'I', 'drunk', 'of', 'Siren', 'tears']
# Current word count (last 5 words): {'poison': 1, 'feil': 1, '119': 1, 'drunk': 1, 'siren': 1}
# Processing message...
# Received message...
# Decoded line: Distilled from limbecks foul as hell within,
# Cursor position: 78965
# Updated total character count: 78965
# Words in the line: ['Distilled', 'from', 'limbecks', 'foul', 'as', 'hell', 'within,']
# Current word count (last 5 words): {'siren': 1, 'limbecks': 1, 'foul': 1, 'hell': 1, 'within,': 1}
# Processing message...
# Received message...
# Decoded line: Applying fears to hopes, and hopes to fears,
# Cursor position: 79012
# Updated total character count: 79012
# Words in the line: ['Applying', 'fears', 'to', 'hopes,', 'and', 'hopes', 'to', 'fears,']
# Current word count (last 5 words): {'hell': 1, 'within,': 1, 'applying': 1, 'hopes,': 1, 'hopes': 1}
# Processing message...
# Received message...
# Decoded line: Still losing when I saw my self to win!
# Cursor position: 79054
# Updated total character count: 79054
# Words in the line: ['Still', 'losing', 'when', 'I', 'saw', 'my', 'self', 'to', 'win!']
# Current word count (last 5 words): {'within,': 1, 'applying': 1, 'hopes,': 1, 'hopes': 1, 'win!': 1}
# Processing message...
# Received message...
# Decoded line: What wretched errors hath my heart committed,
# Cursor position: 79102
# Updated total character count: 79102
# Words in the line: ['What', 'wretched', 'errors', 'hath', 'my', 'heart', 'committed,']
# Current word count (last 5 words): {'applying': 1, 'hopes,': 1, 'hopes': 1, 'win!': 1, 'committed,': 1}
# Processing message...
# Received message...
# Decoded line: Whilst it hath thought it self so blessed never!
# Cursor position: 79153
# Updated total character count: 79153
# Words in the line: ['Whilst', 'it', 'hath', 'thought', 'it', 'self', 'so', 'blessed', 'never!']
# Current word count (last 5 words): {'hopes,': 1, 'hopes': 1, 'win!': 1, 'committed,': 1, 'never!': 1}
# Processing message...
# Received message...
# Decoded line: How have mine eyes out of their spheres been fitted
# Cursor position: 79207
# Updated total character count: 79207
# Words in the line: ['How', 'have', 'mine', 'eyes', 'out', 'of', 'their', 'spheres', 'been', 'fitted']
# Current word count (last 5 words): {'win!': 1, 'committed,': 1, 'never!': 1, 'spheres': 1, 'fitted': 1}
# Processing message...
# Received message...
# Decoded line: In the distraction of this madding fever!
# Cursor position: 79251
# Updated total character count: 79251
# Words in the line: ['In', 'the', 'distraction', 'of', 'this', 'madding', 'fever!']
# Current word count (last 5 words): {'spheres': 1, 'fitted': 1, 'distraction': 1, 'madding': 1, 'fever!': 1}
# Processing message...
# Received message...
# Decoded line: O benefit of ill, now I find true
# Cursor position: 79287
# Updated total character count: 79287
# Words in the line: ['O', 'benefit', 'of', 'ill,', 'now', 'I', 'find', 'true']
# Current word count (last 5 words): {'spheres': 1, 'fitted': 1, 'distraction': 1, 'madding': 1, 'fever!': 1}
#
# Top 5 most frequent words:
# and: 382
# the: 361
# of: 309
# to: 304
# my: 276
# Processing message...
# Received message...
# Decoded line: That better is, by evil still made better.
# Cursor position: 79332
# Updated total character count: 79332
# Words in the line: ['That', 'better', 'is,', 'by', 'evil', 'still', 'made', 'better.']
# Current word count (last 5 words): {'fitted': 1, 'distraction': 1, 'madding': 1, 'fever!': 1, 'better.': 1}
# Processing message...
# Received message...
# Decoded line: And ruined love when it is built anew
# Cursor position: 79372
# Updated total character count: 79372
# Words in the line: ['And', 'ruined', 'love', 'when', 'it', 'is', 'built', 'anew']
# Current word count (last 5 words): {'madding': 1, 'fever!': 1, 'better.': 1, 'built': 1, 'anew': 1}
# Processing message...
# Received message...
# Decoded line: Grows fairer than at first, more strong, far greater.
# Cursor position: 79428
# Updated total character count: 79428
# Words in the line: ['Grows', 'fairer', 'than', 'at', 'first,', 'more', 'strong,', 'far', 'greater.']
# Current word count (last 5 words): {'fever!': 1, 'better.': 1, 'built': 1, 'anew': 1, 'greater.': 1}
# Processing message...
# Received message...
# Decoded line: So I return rebuked to my content,
# Cursor position: 79467
# Updated total character count: 79467
# Words in the line: ['So', 'I', 'return', 'rebuked', 'to', 'my', 'content,']
# Current word count (last 5 words): {'better.': 1, 'built': 1, 'anew': 1, 'greater.': 1, 'rebuked': 1}
# Processing message...
# Received message...
# Decoded line: And gain by ills thrice more than I have spent.
# Cursor position: 79519
# Updated total character count: 79519
# Words in the line: ['And', 'gain', 'by', 'ills', 'thrice', 'more', 'than', 'I', 'have', 'spent.']
# Current word count (last 5 words): {'better.': 1, 'built': 1, 'anew': 1, 'greater.': 1, 'rebuked': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 79520
# Updated total character count: 79520
# Words in the line: []
# Current word count (last 5 words): {'better.': 1, 'built': 1, 'anew': 1, 'greater.': 1, 'rebuked': 1}
# Processing message...
# Received message...
# Decoded line:
# Cursor position: 79521
# Updated total character count: 79521
# Words in the line: []
# Current word count (last 5 words): {'better.': 1, 'built': 1, 'anew': 1, 'greater.': 1, 'rebuked': 1}
# Processing message...
# Received message...
# Decoded line: 120
# Cursor position: 79546
# Updated total character count: 79546
# Words in the line: ['120']
# Current word count (last 5 words): {'built': 1, 'anew': 1, 'greater.': 1, 'rebuked': 1, '120': 1}
# Processing message...
# Received message...
# Decoded line: That you were once unkind befriends me now,
# Cursor position: 79592
# Updated total character count: 79592
# Words in the line: ['That', 'you', 'were', 'once', 'unkind', 'befriends', 'me', 'now,']
# Current word count (last 5 words): {'greater.': 1, 'rebuked': 1, '120': 1, 'unkind': 1, 'befriends': 1}
# Processing message...
# Received message...
# Decoded line: And for that sorrow, which I then did feel,
# Cursor position: 79638
# Updated total character count: 79638
# Words in the line: ['And', 'for', 'that', 'sorrow,', 'which', 'I', 'then', 'did', 'feel,']
# Current word count (last 5 words): {'rebuked': 1, '120': 1, 'unkind': 1, 'befriends': 1, 'feel,': 1}
#
# Top 5 most frequent words:
# and: 385
# the: 361
# of: 309
# to: 305
# my: 277
# Processing message...
# Received message...
# Decoded line: Needs must I under my transgression bow,
# Cursor position: 79681
# Updated total character count: 79681
# Words in the line: ['Needs', 'must', 'I', 'under', 'my', 'transgression', 'bow,']
# Current word count (last 5 words): {'120': 1, 'unkind': 1, 'befriends': 1, 'feel,': 1, 'transgression': 1}
# Processing message...
# Received message...
# Decoded line: Unless my nerves were brass or hammered steel.
# Cursor position: 79730
# Updated total character count: 79730
# Words in the line: ['Unless', 'my', 'nerves', 'were', 'brass', 'or', 'hammered', 'steel.']
# Current word count (last 5 words): {'feel,': 1, 'transgression': 1, 'nerves': 1, 'hammered': 1, 'steel.': 1}
# Processing message...
# Received message...
# Decoded line: For if you were by my unkindness shaken
# Cursor position: 79772
# Updated total character count: 79772
# Words in the line: ['For', 'if', 'you', 'were', 'by', 'my', 'unkindness', 'shaken']
# Current word count (last 5 words): {'nerves': 1, 'hammered': 1, 'steel.': 1, 'unkindness': 1, 'shaken': 1}
# Processing message...
# Received message...
# Decoded line: As I by yours, y'have passed a hell of time,
# Cursor position: 79819
# Updated total character count: 79819
# Words in the line: ['As', 'I', 'by', 'yours,', "y'have", 'passed', 'a', 'hell', 'of', 'time,']
# Current word count (last 5 words): {'hammered': 1, 'steel.': 1, 'unkindness': 1, 'shaken': 1, "y'have": 1}
# Processing message...
# Received message...
# Decoded line: And I a tyrant have no leisure taken
# Cursor position: 79858
# Updated total character count: 79858
# Words in the line: ['And', 'I', 'a', 'tyrant', 'have', 'no', 'leisure', 'taken']
# Current word count (last 5 words): {'steel.': 1, 'unkindness': 1, 'shaken': 1, "y'have": 1, 'taken': 1}
# Processing message...
# Received message...
# Decoded line: To weigh how once I suffered in your crime.
# Cursor position: 79904
# Updated total character count: 79904
# Words in the line: ['To', 'weigh', 'how', 'once', 'I', 'suffered', 'in', 'your', 'crime.']
# Current word count (last 5 words): {'shaken': 1, "y'have": 1, 'taken': 1, 'weigh': 1, 'suffered': 1}
# No message received, continuing to poll...
# No message received, continuing to poll...
#
# Top 5 most frequent words:
# and: 386
# the: 361
# of: 310
# to: 306
# my: 280
# No message received, continuing to poll...
# No message received, continuing to poll...
# No message received, continuing to poll...
